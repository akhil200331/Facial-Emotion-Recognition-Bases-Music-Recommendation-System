# %%
import os
import keras
import itertools
import numpy as np
import pandas as pd
import seaborn as sn
from collections import Counter
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras import regularizers

from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,EarlyStopping

from IPython.display import Image, HTML
from tensorflow.keras.utils import plot_model

# %%
train_dir = '../input/fer2013/train/'
test_dir = '../input/fer2013/test/'

# Image size

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)

BS = 64
EPOCHS = 50
ADAM_LEARNING_RATE = 0.0001
PATIENCE =10

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   featurewise_center=False,
                                   featurewise_std_normalization=False,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)

test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
import os
import pandas as pd
from IPython.core.display import HTML

def count_exp(path, set_):
    dict_ = {}
    if not os.path.exists(path):
        raise ValueError(f"Path does not exist: {path}")
    
    for expression in os.listdir(path):
        dir_ = os.path.join(path, expression)  # Use os.path.join for cross-platform compatibility
        if os.path.isdir(dir_):  # Ensure it's a directory
            dict_[expression] = len(os.listdir(dir_))
    
    return pd.DataFrame(dict_, index=[set_])

# Ensure train_dir and test_dir are correctly defined
train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')

# Fix the append issue
HTML(pd.concat([train_count, test_count]).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>surprise</th>
#       <th>fear</th>
#       <th>angry</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>disgust</th>
#       <th>happy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3171</td>
#       <td>4097</td>
#       <td>3995</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>436</td>
#       <td>7215</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>831</td>
#       <td>1024</td>
#       <td>958</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>111</td>
#       <td>1774</td>
#     </tr>
#   </tbody>
# </table>

# %%
class_labels = test_dataset.class_indices
class_labels
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
train_sample=next(train_dataset)
print(train_sample[0].shape)
# Out:
# (64, 48, 48, 3)

# %%
x = list(test_count.columns)
y1 =train_count.iloc[0].to_list()
y2 = test_count.iloc[0].to_list()
plt.figure(figsize=(12,7))

plt.bar(x, y1, color='blue')
plt.bar(x, y2, bottom=y1, color='violet')
plt.xlabel("Emotions")
plt.ylabel("Train & Test data")
plt.legend(["Train", "Test"], loc='upper left')
plt.title("FER-2013")
plt.show()

# %% [markdown]
# # **AlexNet**

# %%
from tensorflow.keras.layers import Conv2D,MaxPooling2D

# %%
model = Sequential([
    Conv2D(96, (11, 11), strides=4, activation='relu', input_shape=IMAGE_SHAPE),
    BatchNormalization(),
    MaxPooling2D((3, 3), strides=2, padding='same'),  # (12,12,96)

    Conv2D(256, (5, 5), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((3, 3), strides=2, padding='same'),  # (6,6,256)

    Conv2D(384, (3, 3), padding='same', activation='relu'),
    Conv2D(384, (3, 3), padding='same', activation='relu'),
    Conv2D(256, (3, 3), padding='same', activation='relu'),

    # Reduce kernel size & stride to avoid negative dimensions
    MaxPooling2D((2, 2), strides=2, padding='same'),  # (3,3,256)

    Flatten(),
    Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),
    
    Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),
    
    Dense(7, activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer=adam, loss='categorical_crossentropy',metrics=METRICS)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
# Run Model

counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
mcp = ModelCheckpoint('model_alexnet.keras')
es = EarlyStopping(verbose=1, patience=20)

history=model.fit(train_dataset,
                  validation_data=test_dataset,
                  epochs = EPOCHS,
                  verbose =1,
                  callbacks = [lrd,mcp,es], 
                  class_weight = class_weights)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 140s 295ms/step - accuracy: 0.8571 - auc: 0.5687 - f1_score: 0.0036 - loss: 8.1304 - precision: 0.4342 - recall: 0.0019 - val_accuracy: 0.8571 - val_auc: 0.6241 - val_f1_score: 0.0000e+00 - val_loss: 4.8811 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 2/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 125ms/step - accuracy: 0.8577 - auc: 0.6305 - f1_score: 0.0383 - loss: 5.9385 - precision: 0.5451 - recall: 0.0204 - val_accuracy: 0.8571 - val_auc: 0.5575 - val_f1_score: 0.0000e+00 - val_loss: 3.8175 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 3/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8593 - auc: 0.6832 - f1_score: 0.0727 - loss: 4.7783 - precision: 0.6208 - recall: 0.0396 - val_accuracy: 0.8592 - val_auc: 0.6845 - val_f1_score: 0.0523 - val_loss: 2.9690 - val_precision: 0.6769 - val_recall: 0.0277 - learning_rate: 1.0000e-04
# Epoch 4/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8620 - auc: 0.6921 - f1_score: 0.1234 - loss: 4.1785 - precision: 0.6635 - recall: 0.0691 - val_accuracy: 0.8350 - val_auc: 0.5679 - val_f1_score: 0.1446 - val_loss: 2.9719 - val_precision: 0.2778 - val_recall: 0.0971 - learning_rate: 1.0000e-04
# Epoch 5/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8612 - auc: 0.7105 - f1_score: 0.1212 - loss: 3.7196 - precision: 0.6332 - recall: 0.0685 - val_accuracy: 0.8628 - val_auc: 0.7342 - val_f1_score: 0.0900 - val_loss: 2.1863 - val_precision: 0.8597 - val_recall: 0.0469 - learning_rate: 1.0000e-04
# Epoch 6/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.8642 - auc: 0.7331 - f1_score: 0.1684 - loss: 3.3858 - precision: 0.6707 - recall: 0.0978 - val_accuracy: 0.8610 - val_auc: 0.7428 - val_f1_score: 0.2448 - val_loss: 2.0030 - val_precision: 0.5459 - val_recall: 0.1608 - learning_rate: 1.0000e-04
# Epoch 7/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 125ms/step - accuracy: 0.8633 - auc: 0.7348 - f1_score: 0.1710 - loss: 3.2512 - precision: 0.6358 - recall: 0.0998 - val_accuracy: 0.8595 - val_auc: 0.6643 - val_f1_score: 0.1295 - val_loss: 2.0548 - val_precision: 0.5632 - val_recall: 0.0745 - learning_rate: 1.0000e-04
# Epoch 8/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 125ms/step - accuracy: 0.8641 - auc: 0.7352 - f1_score: 0.1837 - loss: 3.1591 - precision: 0.6452 - recall: 0.1087 - val_accuracy: 0.8449 - val_auc: 0.6775 - val_f1_score: 0.1446 - val_loss: 2.0995 - val_precision: 0.3432 - val_recall: 0.0935 - learning_rate: 1.0000e-04
# Epoch 9/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8650 - auc: 0.7508 - f1_score: 0.1996 - loss: 3.0254 - precision: 0.6496 - recall: 0.1192 - val_accuracy: 0.8664 - val_auc: 0.7576 - val_f1_score: 0.1809 - val_loss: 1.7552 - val_precision: 0.7240 - val_recall: 0.1049 - learning_rate: 1.0000e-04
# Epoch 10/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8661 - auc: 0.7578 - f1_score: 0.2097 - loss: 2.9181 - precision: 0.6654 - recall: 0.1259 - val_accuracy: 0.8643 - val_auc: 0.7618 - val_f1_score: 0.1326 - val_loss: 1.7190 - val_precision: 0.7635 - val_recall: 0.0729 - learning_rate: 1.0000e-04
# Epoch 11/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.8663 - auc: 0.7668 - f1_score: 0.2258 - loss: 2.8746 - precision: 0.6513 - recall: 0.1382 - val_accuracy: 0.8624 - val_auc: 0.7338 - val_f1_score: 0.2005 - val_loss: 1.7805 - val_precision: 0.5875 - val_recall: 0.1230 - learning_rate: 1.0000e-04
# Epoch 12/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8663 - auc: 0.7641 - f1_score: 0.2273 - loss: 2.8603 - precision: 0.6493 - recall: 0.1395 - val_accuracy: 0.8620 - val_auc: 0.7397 - val_f1_score: 0.2401 - val_loss: 1.7550 - val_precision: 0.5615 - val_recall: 0.1546 - learning_rate: 1.0000e-04
# Epoch 13/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.8675 - auc: 0.7747 - f1_score: 0.2376 - loss: 2.8180 - precision: 0.6646 - recall: 0.1470 - val_accuracy: 0.8610 - val_auc: 0.7298 - val_f1_score: 0.1938 - val_loss: 1.7739 - val_precision: 0.5644 - val_recall: 0.1191 - learning_rate: 1.0000e-04
# Epoch 14/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8667 - auc: 0.7760 - f1_score: 0.2442 - loss: 2.7870 - precision: 0.6400 - recall: 0.1526 - val_accuracy: 0.8657 - val_auc: 0.7751 - val_f1_score: 0.2104 - val_loss: 1.6441 - val_precision: 0.6551 - val_recall: 0.1259 - learning_rate: 1.0000e-04
# Epoch 15/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8683 - auc: 0.7823 - f1_score: 0.2556 - loss: 2.7497 - precision: 0.6618 - recall: 0.1601 - val_accuracy: 0.8524 - val_auc: 0.7130 - val_f1_score: 0.2424 - val_loss: 1.8946 - val_precision: 0.4546 - val_recall: 0.1668 - learning_rate: 1.0000e-04
# Epoch 16/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8691 - auc: 0.7918 - f1_score: 0.2752 - loss: 2.6657 - precision: 0.6555 - recall: 0.1760 - val_accuracy: 0.8731 - val_auc: 0.8002 - val_f1_score: 0.3050 - val_loss: 1.5583 - val_precision: 0.6984 - val_recall: 0.1964 - learning_rate: 1.0000e-04
# Epoch 17/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8687 - auc: 0.7897 - f1_score: 0.2699 - loss: 2.6786 - precision: 0.6537 - recall: 0.1717 - val_accuracy: 0.8690 - val_auc: 0.7944 - val_f1_score: 0.3444 - val_loss: 1.5947 - val_precision: 0.6032 - val_recall: 0.2431 - learning_rate: 1.0000e-04
# Epoch 18/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8697 - auc: 0.7970 - f1_score: 0.2833 - loss: 2.6164 - precision: 0.6588 - recall: 0.1824 - val_accuracy: 0.8665 - val_auc: 0.7835 - val_f1_score: 0.1839 - val_loss: 1.6053 - val_precision: 0.7191 - val_recall: 0.1077 - learning_rate: 1.0000e-04
# Epoch 19/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8714 - auc: 0.8034 - f1_score: 0.2973 - loss: 2.5951 - precision: 0.6759 - recall: 0.1922 - val_accuracy: 0.8695 - val_auc: 0.7706 - val_f1_score: 0.2895 - val_loss: 1.6426 - val_precision: 0.6498 - val_recall: 0.1879 - learning_rate: 1.0000e-04
# Epoch 20/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8712 - auc: 0.8035 - f1_score: 0.3034 - loss: 2.5733 - precision: 0.6650 - recall: 0.1984 - val_accuracy: 0.8719 - val_auc: 0.8005 - val_f1_score: 0.3415 - val_loss: 1.5608 - val_precision: 0.6401 - val_recall: 0.2359 - learning_rate: 1.0000e-04
# Epoch 21/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8714 - auc: 0.8066 - f1_score: 0.3033 - loss: 2.5557 - precision: 0.6687 - recall: 0.1976 - val_accuracy: 0.8528 - val_auc: 0.6929 - val_f1_score: 0.1954 - val_loss: 1.9116 - val_precision: 0.4463 - val_recall: 0.1273 - learning_rate: 1.0000e-04
# Epoch 22/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8733 - auc: 0.8183 - f1_score: 0.3246 - loss: 2.4755 - precision: 0.6788 - recall: 0.2153 - val_accuracy: 0.8758 - val_auc: 0.8201 - val_f1_score: 0.4008 - val_loss: 1.5000 - val_precision: 0.6447 - val_recall: 0.2914 - learning_rate: 1.0000e-04
# Epoch 23/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8724 - auc: 0.8155 - f1_score: 0.3266 - loss: 2.5041 - precision: 0.6614 - recall: 0.2188 - val_accuracy: 0.8729 - val_auc: 0.8156 - val_f1_score: 0.3228 - val_loss: 1.5054 - val_precision: 0.6705 - val_recall: 0.2169 - learning_rate: 1.0000e-04
# Epoch 24/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8747 - auc: 0.8236 - f1_score: 0.3386 - loss: 2.4445 - precision: 0.6860 - recall: 0.2264 - val_accuracy: 0.8728 - val_auc: 0.8135 - val_f1_score: 0.3225 - val_loss: 1.5101 - val_precision: 0.6728 - val_recall: 0.2129 - learning_rate: 1.0000e-04
# Epoch 25/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - accuracy: 0.8746 - auc: 0.8241 - f1_score: 0.3447 - loss: 2.4253 - precision: 0.6780 - recall: 0.2329 - val_accuracy: 0.8709 - val_auc: 0.8050 - val_f1_score: 0.2677 - val_loss: 1.5384 - val_precision: 0.6998 - val_recall: 0.1686 - learning_rate: 1.0000e-04
# Epoch 26/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8748 - auc: 0.8267 - f1_score: 0.3494 - loss: 2.4200 - precision: 0.6766 - recall: 0.2374 - val_accuracy: 0.8422 - val_auc: 0.7305 - val_f1_score: 0.2745 - val_loss: 1.9542 - val_precision: 0.4006 - val_recall: 0.2111 - learning_rate: 1.0000e-04
# Epoch 27/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - accuracy: 0.8749 - auc: 0.8264 - f1_score: 0.3489 - loss: 2.4138 - precision: 0.6781 - recall: 0.2370 - val_accuracy: 0.8741 - val_auc: 0.8219 - val_f1_score: 0.3272 - val_loss: 1.4810 - val_precision: 0.6888 - val_recall: 0.2165 - learning_rate: 1.0000e-04
# Epoch 28/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8768 - auc: 0.8357 - f1_score: 0.3641 - loss: 2.3389 - precision: 0.6899 - recall: 0.2496 - val_accuracy: 0.8624 - val_auc: 0.7807 - val_f1_score: 0.3147 - val_loss: 1.6462 - val_precision: 0.5450 - val_recall: 0.2219 - learning_rate: 1.0000e-04
# Epoch 29/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8765 - auc: 0.8330 - f1_score: 0.3666 - loss: 2.3826 - precision: 0.6830 - recall: 0.2523 - val_accuracy: 0.8776 - val_auc: 0.8396 - val_f1_score: 0.3680 - val_loss: 1.4157 - val_precision: 0.6990 - val_recall: 0.2513 - learning_rate: 1.0000e-04
# Epoch 30/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8787 - auc: 0.8383 - f1_score: 0.3785 - loss: 2.3295 - precision: 0.7033 - recall: 0.2614 - val_accuracy: 0.8775 - val_auc: 0.8339 - val_f1_score: 0.3735 - val_loss: 1.4350 - val_precision: 0.6902 - val_recall: 0.2591 - learning_rate: 1.0000e-04
# Epoch 31/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8772 - auc: 0.8387 - f1_score: 0.3785 - loss: 2.3241 - precision: 0.6823 - recall: 0.2635 - val_accuracy: 0.8733 - val_auc: 0.8287 - val_f1_score: 0.4174 - val_loss: 1.4915 - val_precision: 0.6073 - val_recall: 0.3193 - learning_rate: 1.0000e-04
# Epoch 32/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 124ms/step - accuracy: 0.8789 - auc: 0.8411 - f1_score: 0.3846 - loss: 2.2821 - precision: 0.6990 - recall: 0.2672 - val_accuracy: 0.8689 - val_auc: 0.7989 - val_f1_score: 0.2635 - val_loss: 1.5608 - val_precision: 0.6621 - val_recall: 0.1679 - learning_rate: 1.0000e-04
# Epoch 33/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.8792 - auc: 0.8479 - f1_score: 0.3915 - loss: 2.2474 - precision: 0.6954 - recall: 0.2748 - val_accuracy: 0.8741 - val_auc: 0.8216 - val_f1_score: 0.3832 - val_loss: 1.4900 - val_precision: 0.6373 - val_recall: 0.2754 - learning_rate: 1.0000e-04
# Epoch 34/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 125ms/step - accuracy: 0.8798 - auc: 0.8464 - f1_score: 0.3992 - loss: 2.2472 - precision: 0.6965 - recall: 0.2817 - val_accuracy: 0.8765 - val_auc: 0.8395 - val_f1_score: 0.3752 - val_loss: 1.4217 - val_precision: 0.6741 - val_recall: 0.2627 - learning_rate: 1.0000e-04
# Epoch 35/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.8803 - auc: 0.8532 - f1_score: 0.4084 - loss: 2.2069 - precision: 0.6920 - recall: 0.2916 - val_accuracy: 0.8755 - val_auc: 0.8292 - val_f1_score: 0.3862 - val_loss: 1.4599 - val_precision: 0.6525 - val_recall: 0.2751 - learning_rate: 1.0000e-04
# Epoch 36/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8818 - auc: 0.8552 - f1_score: 0.4200 - loss: 2.1601 - precision: 0.7004 - recall: 0.3019 - val_accuracy: 0.8763 - val_auc: 0.8285 - val_f1_score: 0.3923 - val_loss: 1.4646 - val_precision: 0.6545 - val_recall: 0.2839 - learning_rate: 1.0000e-04
# Epoch 37/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8835 - auc: 0.8594 - f1_score: 0.4274 - loss: 2.1676 - precision: 0.7149 - recall: 0.3075 - val_accuracy: 0.8788 - val_auc: 0.8384 - val_f1_score: 0.4177 - val_loss: 1.4253 - val_precision: 0.6619 - val_recall: 0.3093 - learning_rate: 1.0000e-04
# Epoch 38/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.8820 - auc: 0.8575 - f1_score: 0.4230 - loss: 2.1656 - precision: 0.6989 - recall: 0.3055 - val_accuracy: 0.8795 - val_auc: 0.8468 - val_f1_score: 0.4260 - val_loss: 1.3978 - val_precision: 0.6642 - val_recall: 0.3158 - learning_rate: 1.0000e-04
# Epoch 39/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8834 - auc: 0.8594 - f1_score: 0.4337 - loss: 2.1596 - precision: 0.7059 - recall: 0.3150 - val_accuracy: 0.8824 - val_auc: 0.8542 - val_f1_score: 0.4595 - val_loss: 1.3748 - val_precision: 0.6690 - val_recall: 0.3497 - learning_rate: 1.0000e-04
# Epoch 40/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8829 - auc: 0.8632 - f1_score: 0.4376 - loss: 2.1216 - precision: 0.6949 - recall: 0.3219 - val_accuracy: 0.8761 - val_auc: 0.8335 - val_f1_score: 0.3767 - val_loss: 1.4440 - val_precision: 0.6677 - val_recall: 0.2637 - learning_rate: 1.0000e-04
# Epoch 41/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8862 - auc: 0.8694 - f1_score: 0.4546 - loss: 2.0764 - precision: 0.7174 - recall: 0.3350 - val_accuracy: 0.8690 - val_auc: 0.8105 - val_f1_score: 0.3790 - val_loss: 1.5653 - val_precision: 0.5859 - val_recall: 0.2835 - learning_rate: 1.0000e-04
# Epoch 42/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8843 - auc: 0.8660 - f1_score: 0.4461 - loss: 2.0817 - precision: 0.7022 - recall: 0.3295 - val_accuracy: 0.8695 - val_auc: 0.8133 - val_f1_score: 0.3492 - val_loss: 1.5285 - val_precision: 0.6068 - val_recall: 0.2458 - learning_rate: 1.0000e-04
# Epoch 43/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.8873 - auc: 0.8738 - f1_score: 0.4659 - loss: 2.0322 - precision: 0.7195 - recall: 0.3462 - val_accuracy: 0.8732 - val_auc: 0.8162 - val_f1_score: 0.3614 - val_loss: 1.5150 - val_precision: 0.6419 - val_recall: 0.2547 - learning_rate: 1.0000e-04
# Epoch 44/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 127ms/step - accuracy: 0.8857 - auc: 0.8706 - f1_score: 0.4554 - loss: 2.0522 - precision: 0.7117 - recall: 0.3361 - val_accuracy: 0.8718 - val_auc: 0.8179 - val_f1_score: 0.3888 - val_loss: 1.5296 - val_precision: 0.6077 - val_recall: 0.2901 - learning_rate: 1.0000e-04
# Epoch 45/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.8878 - auc: 0.8753 - f1_score: 0.4721 - loss: 2.0225 - precision: 0.7171 - recall: 0.3543 - val_accuracy: 0.8794 - val_auc: 0.8475 - val_f1_score: 0.4302 - val_loss: 1.3983 - val_precision: 0.6609 - val_recall: 0.3204 - learning_rate: 1.0000e-04
# Epoch 46/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - accuracy: 0.8873 - auc: 0.8800 - f1_score: 0.4735 - loss: 1.9674 - precision: 0.7094 - recall: 0.3571 - val_accuracy: 0.8756 - val_auc: 0.8378 - val_f1_score: 0.4347 - val_loss: 1.4640 - val_precision: 0.6183 - val_recall: 0.3369 - learning_rate: 1.0000e-04
# Epoch 47/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 131ms/step - accuracy: 0.8900 - auc: 0.8813 - f1_score: 0.4929 - loss: 1.9509 - precision: 0.7191 - recall: 0.3775 - val_accuracy: 0.8826 - val_auc: 0.8547 - val_f1_score: 0.4697 - val_loss: 1.3836 - val_precision: 0.6633 - val_recall: 0.3617 - learning_rate: 1.0000e-04
# Epoch 48/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8911 - auc: 0.8856 - f1_score: 0.4996 - loss: 1.9221 - precision: 0.7238 - recall: 0.3839 - val_accuracy: 0.8809 - val_auc: 0.8520 - val_f1_score: 0.4465 - val_loss: 1.3869 - val_precision: 0.6641 - val_recall: 0.3363 - learning_rate: 1.0000e-04
# Epoch 49/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8901 - auc: 0.8847 - f1_score: 0.4920 - loss: 1.9552 - precision: 0.7218 - recall: 0.3754
# Epoch 49: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - accuracy: 0.8901 - auc: 0.8847 - f1_score: 0.4920 - loss: 1.9552 - precision: 0.7217 - recall: 0.3753 - val_accuracy: 0.8810 - val_auc: 0.8515 - val_f1_score: 0.4495 - val_loss: 1.3892 - val_precision: 0.6624 - val_recall: 0.3409 - learning_rate: 1.0000e-04
# Epoch 50/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 131ms/step - accuracy: 0.8938 - auc: 0.8927 - f1_score: 0.5157 - loss: 1.8550 - precision: 0.7369 - recall: 0.3987 - val_accuracy: 0.8847 - val_auc: 0.8677 - val_f1_score: 0.5048 - val_loss: 1.3467 - val_precision: 0.6519 - val_recall: 0.4147 - learning_rate: 5.0000e-05

# %%
model.save("/kaggle/working/model_alex_net.h5")

# %%
train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 52s 116ms/step - accuracy: 0.8938 - auc: 0.8939 - f1_score: 0.5391 - loss: 1.1867 - precision: 0.7080 - recall: 0.4371
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.8852 - auc: 0.8658 - f1_score: 0.5060 - loss: 1.3546 - precision: 0.6558 - recall: 0.4135

# %%
metric_list = ["Loss","Accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>1.180</td>
#       <td>1.347</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.894</td>
#       <td>0.885</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.710</td>
#       <td>0.652</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.441</td>
#       <td>0.415</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.895</td>
#       <td>0.868</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.543</td>
#       <td>0.504</td>
#     </tr>
#   </tbody>
# </table>

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Confusion matrix, without normalization
#
# [[105  42  92 244 247 104 124]
#  [  5   7  10  28  33  12  16]
#  [112  42  90 280 220 131 149]
#  [153  82 192 482 384 229 252]
#  [115  59 120 358 258 160 163]
#  [106  53 138 327 297 156 170]
#  [ 88  31 119 222 154 110 107]]
# <ipython-input-55-a56f347fa47c>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()
# Out:
# <ipython-input-56-e68e0cb2e8fd>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# # **Alexnet with self attention**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, Flatten, Multiply, Reshape, Activation, Input
from tensorflow.keras.models import Model

# Attention Mechanism: SE Block
def se_block(input_tensor, ratio=16):
    """ Squeeze-and-Excitation Attention Block """
    filters = input_tensor.shape[-1]
    se = GlobalAveragePooling2D()(input_tensor)
    se = Dense(filters // ratio, activation="relu")(se)
    se = Dense(filters, activation="sigmoid")(se)
    se = Reshape((1, 1, filters))(se)
    return Multiply()([input_tensor, se])  # Apply attention

# Model Input
input_layer = Input(shape=(48, 48, 3))

# AlexNet with Attention
x = Conv2D(96, (11, 11), strides=4, activation='relu', padding="same")(input_layer)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=2, padding="same")(x)
x = se_block(x)  # Attention

x = Conv2D(256, (5, 5), padding="same", activation='relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D((3, 3), strides=2, padding="same")(x)
x = se_block(x)  # Attention

x = Conv2D(384, (3, 3), padding="same", activation='relu')(x)
x = Conv2D(384, (3, 3), padding="same", activation='relu')(x)
x = Conv2D(256, (3, 3), padding="same", activation='relu')(x)
x = MaxPooling2D((2, 2), strides=2, padding="same")(x)
x = se_block(x)  # Attention

# Fully Connected Layers
x = Flatten()(x)
x = Dense(4096, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
x = Dropout(0.5)(x)

x = Dense(4096, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001))(x)
x = Dropout(0.5)(x)

output_layer = Dense(7, activation='softmax')(x)

# Create Model
model = Model(inputs=input_layer, outputs=output_layer)

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer=adam, loss='categorical_crossentropy',metrics=METRICS)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_5             │ (None, 48, 48, 3)      │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_25 (Conv2D)        │ (None, 12, 12, 96)     │         34,944 │ input_layer_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 12, 12, 96)     │            384 │ conv2d_25[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_15          │ (None, 6, 6, 96)       │              0 │ batch_normalization_1… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 96)             │              0 │ max_pooling2d_15[0][0] │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_15 (Dense)          │ (None, 6)              │            582 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_16 (Dense)          │ (None, 96)             │            672 │ dense_15[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 1, 1, 96)       │              0 │ dense_16[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 6, 6, 96)       │              0 │ max_pooling2d_15[0][0… │
# │                           │                        │                │ reshape[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_26 (Conv2D)        │ (None, 6, 6, 256)      │        614,656 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 6, 6, 256)      │          1,024 │ conv2d_26[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_16          │ (None, 3, 3, 256)      │              0 │ batch_normalization_1… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 256)            │              0 │ max_pooling2d_16[0][0] │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_17 (Dense)          │ (None, 16)             │          4,112 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_18 (Dense)          │ (None, 256)            │          4,352 │ dense_17[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_1 (Reshape)       │ (None, 1, 1, 256)      │              0 │ dense_18[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 3, 3, 256)      │              0 │ max_pooling2d_16[0][0… │
# │                           │                        │                │ reshape_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_27 (Conv2D)        │ (None, 3, 3, 384)      │        885,120 │ multiply_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_28 (Conv2D)        │ (None, 3, 3, 384)      │      1,327,488 │ conv2d_27[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_29 (Conv2D)        │ (None, 3, 3, 256)      │        884,992 │ conv2d_28[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_17          │ (None, 2, 2, 256)      │              0 │ conv2d_29[0][0]        │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 256)            │              0 │ max_pooling2d_17[0][0] │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_19 (Dense)          │ (None, 16)             │          4,112 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_20 (Dense)          │ (None, 256)            │          4,352 │ dense_19[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_2 (Reshape)       │ (None, 1, 1, 256)      │              0 │ dense_20[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_2 (Multiply)     │ (None, 2, 2, 256)      │              0 │ max_pooling2d_17[0][0… │
# │                           │                        │                │ reshape_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_5 (Flatten)       │ (None, 1024)           │              0 │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_21 (Dense)          │ (None, 4096)           │      4,198,400 │ flatten_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_10 (Dropout)      │ (None, 4096)           │              0 │ dense_21[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_22 (Dense)          │ (None, 4096)           │     16,781,312 │ dropout_10[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_11 (Dropout)      │ (None, 4096)           │              0 │ dense_22[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_23 (Dense)          │ (None, 7)              │         28,679 │ dropout_11[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 24,775,181 (94.51 MB)
#  Trainable params: 24,774,477 (94.51 MB)
#  Non-trainable params: 704 (2.75 KB)

# %%
# Run Model

counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
mcp = ModelCheckpoint('model_alexnet_with_Attention.keras')
es = EarlyStopping(verbose=1, patience=20)

history=model.fit(train_dataset,
                  validation_data=test_dataset,
                  epochs = EPOCHS,
                  verbose =1,
                  callbacks = [lrd,mcp,es], 
                  class_weight = class_weights)
# Out:
# Epoch 1/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 76s 146ms/step - accuracy: 0.8572 - auc: 0.5529 - f1_score: 0.0055 - loss: 7.4640 - precision: 0.5812 - recall: 0.0029 - val_accuracy: 0.8571 - val_auc: 0.5510 - val_f1_score: 0.0000e+00 - val_loss: 3.6603 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 2/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8573 - auc: 0.6353 - f1_score: 0.0385 - loss: 4.6787 - precision: 0.5110 - recall: 0.0205 - val_accuracy: 0.8586 - val_auc: 0.7105 - val_f1_score: 0.0242 - val_loss: 2.5793 - val_precision: 0.8491 - val_recall: 0.0125 - learning_rate: 1.0000e-04
# Epoch 3/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8593 - auc: 0.6888 - f1_score: 0.0799 - loss: 3.8235 - precision: 0.6025 - recall: 0.0437 - val_accuracy: 0.8401 - val_auc: 0.6104 - val_f1_score: 0.0998 - val_loss: 2.4583 - val_precision: 0.2571 - val_recall: 0.0631 - learning_rate: 1.0000e-04
# Epoch 4/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8603 - auc: 0.6991 - f1_score: 0.1103 - loss: 3.4782 - precision: 0.6102 - recall: 0.0615 - val_accuracy: 0.8682 - val_auc: 0.7080 - val_f1_score: 0.1941 - val_loss: 1.9869 - val_precision: 0.7633 - val_recall: 0.1123 - learning_rate: 1.0000e-04
# Epoch 5/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8623 - auc: 0.7194 - f1_score: 0.1370 - loss: 3.2393 - precision: 0.6511 - recall: 0.0779 - val_accuracy: 0.8648 - val_auc: 0.7680 - val_f1_score: 0.1316 - val_loss: 1.7896 - val_precision: 0.7954 - val_recall: 0.0720 - learning_rate: 1.0000e-04
# Epoch 6/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8638 - auc: 0.7336 - f1_score: 0.1710 - loss: 3.1148 - precision: 0.6527 - recall: 0.0998 - val_accuracy: 0.8578 - val_auc: 0.6725 - val_f1_score: 0.1187 - val_loss: 1.9626 - val_precision: 0.5163 - val_recall: 0.0685 - learning_rate: 1.0000e-04
# Epoch 7/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - accuracy: 0.8626 - auc: 0.7362 - f1_score: 0.1703 - loss: 3.0543 - precision: 0.6173 - recall: 0.1001 - val_accuracy: 0.8629 - val_auc: 0.7143 - val_f1_score: 0.1322 - val_loss: 1.8175 - val_precision: 0.6860 - val_recall: 0.0743 - learning_rate: 1.0000e-04
# Epoch 8/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 133ms/step - accuracy: 0.8645 - auc: 0.7507 - f1_score: 0.1885 - loss: 2.9212 - precision: 0.6503 - recall: 0.1118 - val_accuracy: 0.8700 - val_auc: 0.7812 - val_f1_score: 0.2260 - val_loss: 1.6444 - val_precision: 0.7492 - val_recall: 0.1349 - learning_rate: 1.0000e-04
# Epoch 9/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.8641 - auc: 0.7558 - f1_score: 0.1903 - loss: 2.8668 - precision: 0.6351 - recall: 0.1138 - val_accuracy: 0.8638 - val_auc: 0.7349 - val_f1_score: 0.2508 - val_loss: 1.7536 - val_precision: 0.5845 - val_recall: 0.1609 - learning_rate: 1.0000e-04
# Epoch 10/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8650 - auc: 0.7564 - f1_score: 0.2098 - loss: 2.8515 - precision: 0.6372 - recall: 0.1274 - val_accuracy: 0.8651 - val_auc: 0.7495 - val_f1_score: 0.2104 - val_loss: 1.7051 - val_precision: 0.6428 - val_recall: 0.1261 - learning_rate: 1.0000e-04
# Epoch 11/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 135ms/step - accuracy: 0.8671 - auc: 0.7741 - f1_score: 0.2420 - loss: 2.7502 - precision: 0.6489 - recall: 0.1507 - val_accuracy: 0.8673 - val_auc: 0.7609 - val_f1_score: 0.2316 - val_loss: 1.6657 - val_precision: 0.6682 - val_recall: 0.1411 - learning_rate: 1.0000e-04
# Epoch 12/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8670 - auc: 0.7744 - f1_score: 0.2410 - loss: 2.7572 - precision: 0.6490 - recall: 0.1499 - val_accuracy: 0.8701 - val_auc: 0.7756 - val_f1_score: 0.2332 - val_loss: 1.6215 - val_precision: 0.7388 - val_recall: 0.1399 - learning_rate: 1.0000e-04
# Epoch 13/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 136ms/step - accuracy: 0.8671 - auc: 0.7724 - f1_score: 0.2358 - loss: 2.7997 - precision: 0.6591 - recall: 0.1450 - val_accuracy: 0.8690 - val_auc: 0.7868 - val_f1_score: 0.2908 - val_loss: 1.5927 - val_precision: 0.6398 - val_recall: 0.1893 - learning_rate: 1.0000e-04
# Epoch 14/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8681 - auc: 0.7835 - f1_score: 0.2572 - loss: 2.7194 - precision: 0.6560 - recall: 0.1618 - val_accuracy: 0.8663 - val_auc: 0.7840 - val_f1_score: 0.2428 - val_loss: 1.5999 - val_precision: 0.6336 - val_recall: 0.1513 - learning_rate: 1.0000e-04
# Epoch 15/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8674 - auc: 0.7846 - f1_score: 0.2536 - loss: 2.6995 - precision: 0.6467 - recall: 0.1592 - val_accuracy: 0.8702 - val_auc: 0.7967 - val_f1_score: 0.3227 - val_loss: 1.5657 - val_precision: 0.6321 - val_recall: 0.2180 - learning_rate: 1.0000e-04
# Epoch 16/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8693 - auc: 0.7926 - f1_score: 0.2703 - loss: 2.6346 - precision: 0.6641 - recall: 0.1716 - val_accuracy: 0.8540 - val_auc: 0.7323 - val_f1_score: 0.2203 - val_loss: 1.7808 - val_precision: 0.4643 - val_recall: 0.1447 - learning_rate: 1.0000e-04
# Epoch 17/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8695 - auc: 0.7936 - f1_score: 0.2807 - loss: 2.6336 - precision: 0.6585 - recall: 0.1799 - val_accuracy: 0.8713 - val_auc: 0.8096 - val_f1_score: 0.2914 - val_loss: 1.5157 - val_precision: 0.6791 - val_recall: 0.1872 - learning_rate: 1.0000e-04
# Epoch 18/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - accuracy: 0.8711 - auc: 0.8053 - f1_score: 0.2939 - loss: 2.5370 - precision: 0.6732 - recall: 0.1899 - val_accuracy: 0.8572 - val_auc: 0.7175 - val_f1_score: 0.2168 - val_loss: 1.8397 - val_precision: 0.5010 - val_recall: 0.1395 - learning_rate: 1.0000e-04
# Epoch 19/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - accuracy: 0.8705 - auc: 0.8059 - f1_score: 0.2970 - loss: 2.5165 - precision: 0.6601 - recall: 0.1934 - val_accuracy: 0.8691 - val_auc: 0.7951 - val_f1_score: 0.3021 - val_loss: 1.5680 - val_precision: 0.6331 - val_recall: 0.1995 - learning_rate: 1.0000e-04
# Epoch 20/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.8716 - auc: 0.8106 - f1_score: 0.3053 - loss: 2.5251 - precision: 0.6691 - recall: 0.2000 - val_accuracy: 0.8640 - val_auc: 0.7799 - val_f1_score: 0.2407 - val_loss: 1.6175 - val_precision: 0.5925 - val_recall: 0.1531 - learning_rate: 1.0000e-04
# Epoch 21/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 135ms/step - accuracy: 0.8720 - auc: 0.8110 - f1_score: 0.3070 - loss: 2.4925 - precision: 0.6739 - recall: 0.2009 - val_accuracy: 0.8681 - val_auc: 0.7984 - val_f1_score: 0.3605 - val_loss: 1.5780 - val_precision: 0.5852 - val_recall: 0.2627 - learning_rate: 1.0000e-04
# Epoch 22/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 134ms/step - accuracy: 0.8728 - auc: 0.8162 - f1_score: 0.3232 - loss: 2.4431 - precision: 0.6717 - recall: 0.2145 - val_accuracy: 0.8635 - val_auc: 0.7448 - val_f1_score: 0.2229 - val_loss: 1.7148 - val_precision: 0.5960 - val_recall: 0.1375 - learning_rate: 1.0000e-04
# Epoch 23/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 141ms/step - accuracy: 0.8724 - auc: 0.8187 - f1_score: 0.3207 - loss: 2.4777 - precision: 0.6683 - recall: 0.2130 - val_accuracy: 0.8527 - val_auc: 0.7097 - val_f1_score: 0.2207 - val_loss: 1.8867 - val_precision: 0.4523 - val_recall: 0.1460 - learning_rate: 1.0000e-04
# Epoch 24/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 135ms/step - accuracy: 0.8745 - auc: 0.8279 - f1_score: 0.3350 - loss: 2.4024 - precision: 0.6868 - recall: 0.2239 - val_accuracy: 0.8735 - val_auc: 0.8174 - val_f1_score: 0.3851 - val_loss: 1.5004 - val_precision: 0.6300 - val_recall: 0.2782 - learning_rate: 1.0000e-04
# Epoch 25/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8745 - auc: 0.8254 - f1_score: 0.3418 - loss: 2.4048 - precision: 0.6790 - recall: 0.2303 - val_accuracy: 0.8707 - val_auc: 0.8108 - val_f1_score: 0.3551 - val_loss: 1.5273 - val_precision: 0.6166 - val_recall: 0.2505 - learning_rate: 1.0000e-04
# Epoch 26/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8764 - auc: 0.8325 - f1_score: 0.3590 - loss: 2.3618 - precision: 0.6898 - recall: 0.2446 - val_accuracy: 0.8717 - val_auc: 0.8175 - val_f1_score: 0.3380 - val_loss: 1.4960 - val_precision: 0.6419 - val_recall: 0.2310 - learning_rate: 1.0000e-04
# Epoch 27/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8766 - auc: 0.8338 - f1_score: 0.3662 - loss: 2.3512 - precision: 0.6855 - recall: 0.2515 - val_accuracy: 0.8689 - val_auc: 0.8046 - val_f1_score: 0.3505 - val_loss: 1.5545 - val_precision: 0.5997 - val_recall: 0.2481 - learning_rate: 1.0000e-04
# Epoch 28/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 132ms/step - accuracy: 0.8772 - auc: 0.8394 - f1_score: 0.3750 - loss: 2.3101 - precision: 0.6841 - recall: 0.2607 - val_accuracy: 0.8713 - val_auc: 0.8144 - val_f1_score: 0.3551 - val_loss: 1.5119 - val_precision: 0.6236 - val_recall: 0.2492 - learning_rate: 1.0000e-04
# Epoch 29/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - accuracy: 0.8769 - auc: 0.8357 - f1_score: 0.3687 - loss: 2.3240 - precision: 0.6869 - recall: 0.2541 - val_accuracy: 0.8756 - val_auc: 0.8309 - val_f1_score: 0.4012 - val_loss: 1.4573 - val_precision: 0.6396 - val_recall: 0.2959 - learning_rate: 1.0000e-04
# Epoch 30/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8778 - auc: 0.8399 - f1_score: 0.3804 - loss: 2.2821 - precision: 0.6878 - recall: 0.2644 - val_accuracy: 0.8597 - val_auc: 0.7733 - val_f1_score: 0.2773 - val_loss: 1.6767 - val_precision: 0.5245 - val_recall: 0.1906 - learning_rate: 1.0000e-04
# Epoch 31/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 129ms/step - accuracy: 0.8783 - auc: 0.8443 - f1_score: 0.3894 - loss: 2.2553 - precision: 0.6841 - recall: 0.2744 - val_accuracy: 0.8819 - val_auc: 0.8500 - val_f1_score: 0.4248 - val_loss: 1.3708 - val_precision: 0.6971 - val_recall: 0.3062 - learning_rate: 1.0000e-04
# Epoch 32/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8796 - auc: 0.8485 - f1_score: 0.3939 - loss: 2.2320 - precision: 0.6977 - recall: 0.2769 - val_accuracy: 0.8787 - val_auc: 0.8447 - val_f1_score: 0.4056 - val_loss: 1.3948 - val_precision: 0.6753 - val_recall: 0.2912 - learning_rate: 1.0000e-04
# Epoch 33/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8806 - auc: 0.8509 - f1_score: 0.4025 - loss: 2.1997 - precision: 0.7033 - recall: 0.2839 - val_accuracy: 0.8728 - val_auc: 0.8192 - val_f1_score: 0.3614 - val_loss: 1.4957 - val_precision: 0.6377 - val_recall: 0.2538 - learning_rate: 1.0000e-04
# Epoch 34/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - accuracy: 0.8803 - auc: 0.8514 - f1_score: 0.4054 - loss: 2.1993 - precision: 0.6948 - recall: 0.2884 - val_accuracy: 0.8739 - val_auc: 0.8216 - val_f1_score: 0.3814 - val_loss: 1.4922 - val_precision: 0.6372 - val_recall: 0.2721 - learning_rate: 1.0000e-04
# Epoch 35/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - accuracy: 0.8817 - auc: 0.8553 - f1_score: 0.4168 - loss: 2.1712 - precision: 0.7030 - recall: 0.2981 - val_accuracy: 0.8758 - val_auc: 0.8291 - val_f1_score: 0.4175 - val_loss: 1.4760 - val_precision: 0.6310 - val_recall: 0.3143 - learning_rate: 1.0000e-04
# Epoch 36/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8822 - auc: 0.8584 - f1_score: 0.4226 - loss: 2.1476 - precision: 0.7032 - recall: 0.3041 - val_accuracy: 0.8731 - val_auc: 0.8315 - val_f1_score: 0.4153 - val_loss: 1.4696 - val_precision: 0.6077 - val_recall: 0.3157 - learning_rate: 1.0000e-04
# Epoch 37/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8826 - auc: 0.8597 - f1_score: 0.4295 - loss: 2.1513 - precision: 0.7005 - recall: 0.3115 - val_accuracy: 0.8711 - val_auc: 0.8243 - val_f1_score: 0.4021 - val_loss: 1.4954 - val_precision: 0.5954 - val_recall: 0.3055 - learning_rate: 1.0000e-04
# Epoch 38/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 132ms/step - accuracy: 0.8839 - auc: 0.8623 - f1_score: 0.4368 - loss: 2.1212 - precision: 0.7088 - recall: 0.3178 - val_accuracy: 0.8807 - val_auc: 0.8505 - val_f1_score: 0.4331 - val_loss: 1.3821 - val_precision: 0.6736 - val_recall: 0.3194 - learning_rate: 1.0000e-04
# Epoch 39/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 135ms/step - accuracy: 0.8846 - auc: 0.8672 - f1_score: 0.4490 - loss: 2.0786 - precision: 0.7039 - recall: 0.3315 - val_accuracy: 0.8756 - val_auc: 0.8358 - val_f1_score: 0.4015 - val_loss: 1.4416 - val_precision: 0.6409 - val_recall: 0.2937 - learning_rate: 1.0000e-04
# Epoch 40/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.8870 - auc: 0.8739 - f1_score: 0.4674 - loss: 2.0146 - precision: 0.7126 - recall: 0.3501 - val_accuracy: 0.8818 - val_auc: 0.8530 - val_f1_score: 0.4500 - val_loss: 1.3776 - val_precision: 0.6686 - val_recall: 0.3423 - learning_rate: 1.0000e-04
# Epoch 41/50
# 446/449 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.8874 - auc: 0.8736 - f1_score: 0.4679 - loss: 2.0119 - precision: 0.7178 - recall: 0.3488
# Epoch 41: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - accuracy: 0.8874 - auc: 0.8736 - f1_score: 0.4678 - loss: 2.0121 - precision: 0.7178 - recall: 0.3488 - val_accuracy: 0.8648 - val_auc: 0.8076 - val_f1_score: 0.3662 - val_loss: 1.5738 - val_precision: 0.5548 - val_recall: 0.2729 - learning_rate: 1.0000e-04
# Epoch 42/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - accuracy: 0.8892 - auc: 0.8806 - f1_score: 0.4806 - loss: 1.9691 - precision: 0.7245 - recall: 0.3619 - val_accuracy: 0.8827 - val_auc: 0.8629 - val_f1_score: 0.4737 - val_loss: 1.3366 - val_precision: 0.6581 - val_recall: 0.3722 - learning_rate: 5.0000e-05
# Epoch 43/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 131ms/step - accuracy: 0.8940 - auc: 0.8906 - f1_score: 0.5186 - loss: 1.8739 - precision: 0.7358 - recall: 0.4026 - val_accuracy: 0.8851 - val_auc: 0.8655 - val_f1_score: 0.4907 - val_loss: 1.3259 - val_precision: 0.6694 - val_recall: 0.3865 - learning_rate: 5.0000e-05
# Epoch 44/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - accuracy: 0.8948 - auc: 0.8944 - f1_score: 0.5255 - loss: 1.8369 - precision: 0.7366 - recall: 0.4098 - val_accuracy: 0.8822 - val_auc: 0.8580 - val_f1_score: 0.4766 - val_loss: 1.3670 - val_precision: 0.6501 - val_recall: 0.3805 - learning_rate: 5.0000e-05
# Epoch 45/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - accuracy: 0.8953 - auc: 0.8941 - f1_score: 0.5292 - loss: 1.8180 - precision: 0.7380 - recall: 0.4146 - val_accuracy: 0.8821 - val_auc: 0.8614 - val_f1_score: 0.4813 - val_loss: 1.3509 - val_precision: 0.6457 - val_recall: 0.3870 - learning_rate: 5.0000e-05
# Epoch 46/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8953 - auc: 0.8946 - f1_score: 0.5280 - loss: 1.8402 - precision: 0.7391 - recall: 0.4132 - val_accuracy: 0.8854 - val_auc: 0.8703 - val_f1_score: 0.5045 - val_loss: 1.3111 - val_precision: 0.6589 - val_recall: 0.4099 - learning_rate: 5.0000e-05
# Epoch 47/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8964 - auc: 0.8988 - f1_score: 0.5371 - loss: 1.7907 - precision: 0.7401 - recall: 0.4234 - val_accuracy: 0.8791 - val_auc: 0.8518 - val_f1_score: 0.4580 - val_loss: 1.3918 - val_precision: 0.6349 - val_recall: 0.3615 - learning_rate: 5.0000e-05
# Epoch 48/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8981 - auc: 0.9040 - f1_score: 0.5489 - loss: 1.7433 - precision: 0.7453 - recall: 0.4358 - val_accuracy: 0.8821 - val_auc: 0.8601 - val_f1_score: 0.4826 - val_loss: 1.3567 - val_precision: 0.6452 - val_recall: 0.3876 - learning_rate: 5.0000e-05
# Epoch 49/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 127ms/step - accuracy: 0.8988 - auc: 0.9049 - f1_score: 0.5540 - loss: 1.7455 - precision: 0.7462 - recall: 0.4420 - val_accuracy: 0.8824 - val_auc: 0.8609 - val_f1_score: 0.4770 - val_loss: 1.3515 - val_precision: 0.6532 - val_recall: 0.3771 - learning_rate: 5.0000e-05
# Epoch 50/50
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 133ms/step - accuracy: 0.9000 - auc: 0.9078 - f1_score: 0.5615 - loss: 1.7024 - precision: 0.7497 - recall: 0.4509 - val_accuracy: 0.8760 - val_auc: 0.8475 - val_f1_score: 0.4497 - val_loss: 1.4183 - val_precision: 0.6135 - val_recall: 0.3571 - learning_rate: 5.0000e-05

# %%
model.save("/kaggle/working/model_alex_net_with_attention.h5")

# %%
train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 54s 121ms/step - accuracy: 0.8935 - auc: 0.8941 - f1_score: 0.5244 - loss: 1.1762 - precision: 0.7226 - recall: 0.4133
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.8766 - auc: 0.8494 - f1_score: 0.4537 - loss: 1.4075 - precision: 0.6165 - recall: 0.3600

# %%
metric_list = ["Loss","Accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>1.184</td>
#       <td>1.418</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.893</td>
#       <td>0.876</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.720</td>
#       <td>0.613</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.409</td>
#       <td>0.357</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.893</td>
#       <td>0.848</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.520</td>
#       <td>0.452</td>
#     </tr>
#   </tbody>
# </table>

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Confusion matrix, without normalization
#
# [[222  22 172 195  98 119 130]
#  [ 20   2  20  25  16  12  16]
#  [205  22 194 195 125 121 162]
#  [389  32 322 341 231 195 264]
#  [267  28 236 230 169 143 160]
#  [260  23 233 259 144 146 182]
#  [181  24 156 174 101  86 109]]
# <ipython-input-66-a56f347fa47c>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()
# Out:
# <ipython-input-67-e68e0cb2e8fd>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
