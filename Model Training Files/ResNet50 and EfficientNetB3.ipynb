# %%
import os
import keras
import itertools
import numpy as np
import pandas as pd
import seaborn as sn
from collections import Counter
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img

from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications import ResNet50,EfficientNetB3
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization ,Activation, GlobalAveragePooling2D
from tensorflow.keras.layers import GaussianNoise
from tensorflow.keras import regularizers

from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint,EarlyStopping

from IPython.display import Image, HTML
from tensorflow.keras.utils import plot_model

# %%
train_dir = '../input/fer2013/train/'
test_dir = '../input/fer2013/test/'

# Image size

IMAGE_SIZE = (48,48)
IMAGE_SHAPE = IMAGE_SIZE + (3,)

BS = 64
EPOCHS = 100
ADAM_LEARNING_RATE = 0.0001
PATIENCE =10

classes=['Angry','Disgust','Fear','Happy','Neutral','Sad','Surprise']

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   featurewise_center=False,
                                   featurewise_std_normalization=False,
                                   rotation_range=10,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = train_dir,
                                                   target_size = IMAGE_SIZE,
                                                   class_mode = 'categorical',
                                                   batch_size = BS)

test_dataset = test_datagen.flow_from_directory(directory = test_dir,
                                                  target_size = IMAGE_SIZE,
                                                  class_mode = 'categorical',
                                                  shuffle =True,
                                                  batch_size = BS)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
import os
import pandas as pd
from IPython.core.display import HTML

def count_exp(path, set_):
    dict_ = {}
    if not os.path.exists(path):
        raise ValueError(f"Path does not exist: {path}")
    
    for expression in os.listdir(path):
        dir_ = os.path.join(path, expression)  # Use os.path.join for cross-platform compatibility
        if os.path.isdir(dir_):  # Ensure it's a directory
            dict_[expression] = len(os.listdir(dir_))
    
    return pd.DataFrame(dict_, index=[set_])

# Ensure train_dir and test_dir are correctly defined
train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')

# Fix the append issue
HTML(pd.concat([train_count, test_count]).to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>surprise</th>
#       <th>fear</th>
#       <th>angry</th>
#       <th>neutral</th>
#       <th>sad</th>
#       <th>disgust</th>
#       <th>happy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>train</th>
#       <td>3171</td>
#       <td>4097</td>
#       <td>3995</td>
#       <td>4965</td>
#       <td>4830</td>
#       <td>436</td>
#       <td>7215</td>
#     </tr>
#     <tr>
#       <th>test</th>
#       <td>831</td>
#       <td>1024</td>
#       <td>958</td>
#       <td>1233</td>
#       <td>1247</td>
#       <td>111</td>
#       <td>1774</td>
#     </tr>
#   </tbody>
# </table>

# %%
class_labels = test_dataset.class_indices
class_labels
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
train_sample=next(train_dataset)
print(train_sample[0].shape)
# Out:
# (64, 48, 48, 3)

# %%
x = list(test_count.columns)
y1 =train_count.iloc[0].to_list()
y2 = test_count.iloc[0].to_list()
plt.figure(figsize=(12,7))

plt.bar(x, y1, color='blue')
plt.bar(x, y2, bottom=y1, color='violet')
plt.xlabel("Emotions")
plt.ylabel("Train & Test data")
plt.legend(["Train", "Test"], loc='upper left')
plt.title("FER-2013")
plt.savefig('distribution.png')
plt.show()

# %% [markdown]
# # 1. EfficientNetB3

# %%
base_model = EfficientNetB3(input_shape=IMAGE_SHAPE, include_top=False, weights='imagenet')
base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb3_notop.h5
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model=Sequential()
model.add(base_model)
model.add(BatchNormalization())
model.add(GaussianNoise(0.01))
model.add(GlobalAveragePooling2D())

model.add(Flatten())
model.add(Dense(256, activation='relu',kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(7, activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb3 (Functional)          │ (None, 2, 2, 1536)          │      10,783,535 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 2, 2, 1536)          │           6,144 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gaussian_noise (GaussianNoise)       │ (None, 2, 2, 1536)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1536)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1536)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         393,472 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 7)                   │             903 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 11,218,486 (42.80 MB)
#  Trainable params: 431,111 (1.64 MB)
#  Non-trainable params: 10,787,375 (41.15 MB)

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer=adam, loss='categorical_crossentropy',metrics=METRICS)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
# Run Model

counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
mcp = ModelCheckpoint('model_efficient_net_B3.keras')
es = EarlyStopping(verbose=1, patience=20)

history=model.fit(train_dataset,
                  validation_data=test_dataset,
                  epochs = EPOCHS,
                  verbose =1,
                  callbacks = [lrd,mcp,es], 
                  class_weight = class_weights)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 249s 470ms/step - accuracy: 0.8147 - auc: 0.5007 - f1_score: 0.0846 - loss: 5.6269 - precision: 0.1442 - recall: 0.0603 - val_accuracy: 0.8571 - val_auc: 0.4316 - val_f1_score: 0.0000e+00 - val_loss: 2.6895 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 2/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.8251 - auc: 0.4971 - f1_score: 0.0621 - loss: 5.2493 - precision: 0.1333 - recall: 0.0408 - val_accuracy: 0.8571 - val_auc: 0.4373 - val_f1_score: 0.0000e+00 - val_loss: 2.6383 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 3/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.8314 - auc: 0.5042 - f1_score: 0.0530 - loss: 5.0339 - precision: 0.1345 - recall: 0.0332 - val_accuracy: 0.8571 - val_auc: 0.4465 - val_f1_score: 0.0000e+00 - val_loss: 2.6088 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 4/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 139ms/step - accuracy: 0.8360 - auc: 0.5013 - f1_score: 0.0418 - loss: 4.9675 - precision: 0.1275 - recall: 0.0253 - val_accuracy: 0.8571 - val_auc: 0.4049 - val_f1_score: 0.0000e+00 - val_loss: 2.5870 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 5/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 65s 143ms/step - accuracy: 0.8400 - auc: 0.5026 - f1_score: 0.0383 - loss: 4.7974 - precision: 0.1361 - recall: 0.0225 - val_accuracy: 0.8571 - val_auc: 0.4421 - val_f1_score: 0.0000e+00 - val_loss: 2.5663 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 6/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 139ms/step - accuracy: 0.8429 - auc: 0.5055 - f1_score: 0.0303 - loss: 4.5783 - precision: 0.1290 - recall: 0.0173 - val_accuracy: 0.8571 - val_auc: 0.4217 - val_f1_score: 0.0000e+00 - val_loss: 2.5496 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 7/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8446 - auc: 0.5039 - f1_score: 0.0245 - loss: 4.6282 - precision: 0.1197 - recall: 0.0138 - val_accuracy: 0.8571 - val_auc: 0.4334 - val_f1_score: 0.0000e+00 - val_loss: 2.5294 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 8/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8471 - auc: 0.5048 - f1_score: 0.0205 - loss: 4.4773 - precision: 0.1219 - recall: 0.0113 - val_accuracy: 0.8571 - val_auc: 0.4309 - val_f1_score: 0.0000e+00 - val_loss: 2.5161 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 9/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s
- precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.4189 - val_f1_score: 0.0000e+00 - val_loss: 1.9768 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 86/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.8571 - auc: 0.4969 - f1_score: 0.0000e+00 - loss: 3.4626 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.4351 - val_f1_score: 0.0000e+00 - val_loss: 1.9760 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 87/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8571 - auc: 0.5082 - f1_score: 0.0000e+00 - loss: 3.3836 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.4740 - val_f1_score: 0.0000e+00 - val_loss: 1.9669 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 88/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 131ms/step - accuracy: 0.8571 - auc: 0.5108 - f1_score: 0.0000e+00 - loss: 3.4291 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.4571 - val_f1_score: 0.0000e+00 - val_loss: 1.9661 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 89/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 67s 147ms/step - accuracy: 0.8571 - auc: 0.5096 - f1_score: 0.0000e+00 - loss: 3.4666 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.4696 - val_f1_score: 0.0000e+00 - val_loss: 1.9657 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 90/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - accuracy: 0.8571 - auc: 0.5130 - f1_score: 0.0000e+00 - loss: 3.4266 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.4727 - val_f1_score: 0.0000e+00 - val_loss: 1.9656 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 91/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - accuracy: 0.8571 - auc: 0.5067 - f1_score: 0.0000e+00 - loss: 3.4252 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.5690 - val_f1_score: 0.0000e+00 - val_loss: 1.9560 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 92/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - accuracy: 0.8571 - auc: 0.5197 - f1_score: 0.0000e+00 - loss: 3.4530 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.5815 - val_f1_score: 0.0000e+00 - val_loss: 1.9546 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 93/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - accuracy: 0.8571 - auc: 0.5208 - f1_score: 0.0000e+00 - loss: 3.4057 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.5144 - val_f1_score: 0.0000e+00 - val_loss: 1.9607 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 94/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 130ms/step - accuracy: 0.8571 - auc: 0.5161 - f1_score: 0.0000e+00 - loss: 3.4419 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.4994 - val_f1_score: 0.0000e+00 - val_loss: 1.9612 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 95/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8571 - auc: 0.5097 - f1_score: 0.0000e+00 - loss: 3.4539 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.5422 - val_f1_score: 0.0000e+00 - val_loss: 1.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 96/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 131ms/step - accuracy: 0.8571 - auc: 0.5192 - f1_score: 0.0000e+00 - loss: 3.4399 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.5484 - val_f1_score: 0.0000e+00 - val_loss: 1.9552 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 97/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 132ms/step - accuracy: 0.8571 - auc: 0.5104 - f1_score: 0.0000e+00 - loss: 3.4383 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.4612 - val_f1_score: 0.0000e+00 - val_loss: 1.9610 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 98/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8571 - auc: 0.5119 - f1_score: 0.0000e+00 - loss: 3.4640 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.5297 - val_f1_score: 0.0000e+00 - val_loss: 1.9574 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 99/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 59s 129ms/step - accuracy: 0.8571 - auc: 0.5141 - f1_score: 0.0000e+00 - loss: 3.4949 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.5752 - val_f1_score: 0.0000e+00 - val_loss: 1.9521 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 100/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 57s 126ms/step - accuracy: 0.8571 - auc: 0.5147 - f1_score: 0.0000e+00 - loss: 3.4156 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_accuracy: 0.8571 - val_auc: 0.5010 - val_f1_score: 0.0000e+00 - val_loss: 1.9585 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 5.0000e-05

# %%
model.save("/kaggle/working/model_efficient_net_B3.h5")

# %%
train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 58s 128ms/step - accuracy: 0.8571 - auc: 0.4940 - f1_score: 0.0000e+00 - loss: 1.9593 - precision: 0.0000e+00 - recall: 0.0000e+00
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.8571 - auc: 0.5004 - f1_score: 0.0000e+00 - loss: 1.9586 - precision: 0.0000e+00 - recall: 0.0000e+00

# %%
metric_list = ["Loss","Accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>1.959</td>
#       <td>1.959</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.857</td>
#       <td>0.857</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.495</td>
#       <td>0.501</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.000</td>
#       <td>0.000</td>
#     </tr>
#   </tbody>
# </table>

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 20s 118ms/step

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Confusion matrix, without normalization
#
# [[   0    0   91    0  600    0  267]
#  [   0    0   10    0   68    0   33]
#  [   1    0  118    0  605    0  300]
#  [   0    0  221    0 1045    0  508]
#  [   1    0  144    0  711    0  377]
#  [   1    1  132    0  749    0  364]
#  [   1    0   81    0  492    0  257]]
# <ipython-input-18-a56f347fa47c>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor
 512)      │      2,359,808 │ conv5_block1_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_2_bn         │ (None, 2, 2, 512)      │          2,048 │ conv5_block1_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_2_relu       │ (None, 2, 2, 512)      │              0 │ conv5_block1_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_0_conv       │ (None, 2, 2, 2048)     │      2,099,200 │ conv4_block6_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_3_conv       │ (None, 2, 2, 2048)     │      1,050,624 │ conv5_block1_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_0_bn         │ (None, 2, 2, 2048)     │          8,192 │ conv5_block1_0_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_3_bn         │ (None, 2, 2, 2048)     │          8,192 │ conv5_block1_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_add (Add)    │ (None, 2, 2, 2048)     │              0 │ conv5_block1_0_bn[0][… │
# │                           │                        │                │ conv5_block1_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block1_out          │ (None, 2, 2, 2048)     │              0 │ conv5_block1_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_1_conv       │ (None, 2, 2, 512)      │      1,049,088 │ conv5_block1_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_1_bn         │ (None, 2, 2, 512)      │          2,048 │ conv5_block2_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_1_relu       │ (None, 2, 2, 512)      │              0 │ conv5_block2_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_2_conv       │ (None, 2, 2, 512)      │      2,359,808 │ conv5_block2_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_2_bn         │ (None, 2, 2, 512)      │          2,048 │ conv5_block2_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_2_relu       │ (None, 2, 2, 512)      │              0 │ conv5_block2_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_3_conv       │ (None, 2, 2, 2048)     │      1,050,624 │ conv5_block2_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_3_bn         │ (None, 2, 2, 2048)     │          8,192 │ conv5_block2_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_add (Add)    │ (None, 2, 2, 2048)     │              0 │ conv5_block1_out[0][0… │
# │                           │                        │                │ conv5_block2_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block2_out          │ (None, 2, 2, 2048)     │              0 │ conv5_block2_add[0][0] │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_1_conv       │ (None, 2, 2, 512)      │      1,049,088 │ conv5_block2_out[0][0] │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_1_bn         │ (None, 2, 2, 512)      │          2,048 │ conv5_block3_1_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_1_relu       │ (None, 2, 2, 512)      │              0 │ conv5_block3_1_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_2_conv       │ (None, 2, 2, 512)      │      2,359,808 │ conv5_block3_1_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_2_bn         │ (None, 2, 2, 512)      │          2,048 │ conv5_block3_2_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_2_relu       │ (None, 2, 2, 512)      │              0 │ conv5_block3_2_bn[0][… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_3_conv       │ (None, 2, 2, 2048)     │      1,050,624 │ conv5_block3_2_relu[0… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_3_bn         │ (None, 2, 2, 2048)     │          8,192 │ conv5_block3_3_conv[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_add (Add)    │ (None, 2, 2, 2048)     │              0 │ conv5_block2_out[0][0… │
# │                           │                        │                │ conv5_block3_3_bn[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv5_block3_out          │ (None, 2, 2, 2048)     │              0 │ conv5_block3_add[0][0] │
# │ (Activation)              │                        │                │                        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 23,534,592 (89.78 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
model=Sequential()
model.add(base_model)
model.add(BatchNormalization())
model.add(GaussianNoise(0.01))
model.add(GlobalAveragePooling2D())

model.add(Flatten())
model.add(Dense(256, activation='relu',kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(128, activation='relu',kernel_regularizer=regularizers.l2(0.001),bias_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.5))

model.add(Dense(7, activation="softmax"))

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 2, 2, 2048)          │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 2, 2, 2048)          │           8,192 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gaussian_noise_1 (GaussianNoise)     │ (None, 2, 2, 2048)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 7)                   │             903 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 24,155,783 (92.15 MB)
#  Trainable params: 23,490,311 (89.61 MB)
#  Non-trainable params: 665,472 (2.54 MB)

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer=adam, loss='categorical_crossentropy',metrics=METRICS)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/base_optimizer.py:33: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
# Run Model

counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
mcp = ModelCheckpoint('model_ResNet50.keras')
es = EarlyStopping(verbose=1, patience=20)

history=model.fit(train_dataset,
                  validation_data=test_dataset,
                  epochs = EPOCHS,
                  verbose =1,
                  callbacks = [lrd,mcp,es], 
                  class_weight = class_weights)
# Out:
# Epoch 1/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 130s 190ms/step - accuracy: 0.8100 - auc: 0.5031 - f1_score: 0.0905 - loss: 5.8474 - precision: 0.1445 - recall: 0.0669 - val_accuracy: 0.8498 - val_auc: 0.5394 - val_f1_score: 0.0274 - val_loss: 2.8857 - val_precision: 0.1854 - val_recall: 0.0152 - learning_rate: 1.0000e-04
# Epoch 2/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 134ms/step - accuracy: 0.8384 - auc: 0.5232 - f1_score: 0.0524 - loss: 5.0359 - precision: 0.1624 - recall: 0.0315 - val_accuracy: 0.8448 - val_auc: 0.5717 - val_f1_score: 0.0713 - val_loss: 3.4050 - val_precision: 0.2480 - val_recall: 0.0425 - learning_rate: 1.0000e-04
# Epoch 3/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 134ms/step - accuracy: 0.8445 - auc: 0.5433 - f1_score: 0.0471 - loss: 4.7255 - precision: 0.1898 - recall: 0.0271 - val_accuracy: 0.8566 - val_auc: 0.5801 - val_f1_score: 0.0096 - val_loss: 2.5407 - val_precision: 0.3636 - val_recall: 0.0050 - learning_rate: 1.0000e-04
# Epoch 4/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 133ms/step - accuracy: 0.8463 - auc: 0.5661 - f1_score: 0.0562 - loss: 4.5216 - precision: 0.2305 - recall: 0.0324 - val_accuracy: 0.8566 - val_auc: 0.6370 - val_f1_score: 0.0738 - val_loss: 2.5282 - val_precision: 0.4795 - val_recall: 0.0408 - learning_rate: 1.0000e-04
# Epoch 5/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 133ms/step - accuracy: 0.8491 - auc: 0.5813 - f1_score: 0.0546 - loss: 4.3590 - precision: 0.2613 - recall: 0.0308 - val_accuracy: 0.8568 - val_auc: 0.5908 - val_f1_score: 0.0111 - val_loss: 2.5106 - val_precision: 0.4227 - val_recall: 0.0057 - learning_rate: 1.0000e-04
# Epoch 6/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 139ms/step - accuracy: 0.8518 - auc: 0.5934 - f1_score: 0.0538 - loss: 4.3093 - precision: 0.3070 - recall: 0.0297 - val_accuracy: 0.8576 - val_auc: 0.6664 - val_f1_score: 0.0121 - val_loss: 2.4169 - val_precision: 0.6716 - val_recall: 0.0063 - learning_rate: 1.0000e-04
# Epoch 7/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 136ms/step - accuracy: 0.8514 - auc: 0.5983 - f1_score: 0.0564 - loss: 4.2200 - precision: 0.3043 - recall: 0.0314 - val_accuracy: 0.8546 - val_auc: 0.6674 - val_f1_score: 0.0098 - val_loss: 2.4519 - val_precision: 0.1823 - val_recall: 0.0052 - learning_rate: 1.0000e-04
# Epoch 8/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 140ms/step - accuracy: 0.8531 - auc: 0.6055 - f1_score: 0.0462 - loss: 4.1404 - precision: 0.3190 - recall: 0.0252 - val_accuracy: 0.8574 - val_auc: 0.5021 - val_f1_score: 0.0092 - val_loss: 2.6149 - val_precision: 0.5965 - val_recall: 0.0047 - learning_rate: 1.0000e-04
# Epoch 9/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 65s 144ms/step - accuracy: 0.8533 - auc: 0.5960 - f1_score: 0.0432 - loss: 4.1862 - precision: 0.3171 - recall: 0.0233 - val_accuracy: 0.8566 - val_auc: 0.6055 - val_f1_score: 0.0893 - val_loss: 2.4773 - val_precision: 0.4808 - val_recall: 0.0488 - learning_rate: 1.0000e-04
# Epoch 10/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 133ms/step - accuracy: 0.8548 - auc: 0.6072 - f1_score: 0.0480 - loss: 4.1228 - precision: 0.3782 - recall: 0.0259 - val_accuracy: 0.8571 - val_auc: 0.6865 - val_f1_score: 2.7229e-04 - val_loss: 2.3726 - val_precision: 0.1667 - val_recall: 1.3931e-04 - learning_rate: 1.0000e-04
# Epoch 11/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.8547 - auc: 0.6017 - f1_score: 0.0393 - loss: 4.1138 - precision: 0.3512 - recall: 0.0210 - val_accuracy: 0.8573 - val_auc: 0.6756 - val_f1_score: 0.0076 - val_loss: 2.3641 - val_precision: 0.5957 - val_recall: 0.0039 - learning_rate: 1.0000e-04
# Epoch 12/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 136ms/step - accuracy: 0.8550 - auc: 0.6121 - f1_score: 0.0434 - loss: 4.0361 - precision: 0.3770 - recall: 0.0233 - val_accuracy: 0.8571 - val_auc: 0.5593 - val_f1_score: 0.0011 - val_loss: 2.4273 - val_precision: 0.4444 - val_recall: 5.5726e-04 - learning_rate: 1.0000e-04
# Epoch 13/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 133ms/step - accuracy: 0.8537 - auc: 0.6002 - f1_score: 0.0283 - loss: 4.0534 - precision: 0.2797 - recall: 0.0150 - val_accuracy: 0.8572 - val_auc: 0.5915 - val_f1_score: 0.0060 - val_loss: 2.3809 - val_precision: 0.5500 - val_recall: 0.0031 - learning_rate: 1.0000e-04
# Epoch 14/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8544 - auc: 0.6160 - f1_score: 0.0445 - loss: 4.0158 - precision: 0.3552 - recall: 0.0240 - val_accuracy: 0.8583 - val_auc: 0.5557 - val_f1_score: 0.0273 - val_loss: 2.3945 - val_precision: 0.6939 - val_recall: 0.0142 - learning_rate: 1.0000e-04
# Epoch 15/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 140ms/step - accuracy: 0.8550 - auc: 0.6146 - f1_score: 0.0455 - loss: 3.8868 - precision: 0.3820 - recall: 0.0244 - val_accuracy: 0.8462 - val_auc: 0.6236 - val_f1_score: 0.1694 - val_loss: 3.4438 - val_precision: 0.3705 - val_recall: 0.1098 - learning_rate: 1.0000e-04
# Epoch 16/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 140ms/step - accuracy: 0.8542 - auc: 0.6227 - f1_score: 0.0506 - loss: 3.9239 - precision: 0.3644 - recall: 0.0274 - val_accuracy: 0.8580 - val_auc: 0.5743 - val_f1_score: 0.0251 - val_loss: 2.3363 - val_precision: 0.6395 - val_recall: 0.0131 - learning_rate: 1.0000e-04
# Epoch 17/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 142ms/step - accuracy: 0.8549 - auc: 0.6284 - f1_score: 0.0567 - loss: 3.8513 - precision: 0.3970 - recall: 0.0309 - val_accuracy: 0.8578 - val_auc: 0.6362 - val_f1_score: 0.0210 - val_loss: 2.2645 - val_precision: 0.6393 - val_recall: 0.0109 - learning_rate: 1.0000e-04
# Epoch 18/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 135ms/step - accuracy: 0.8548 - auc: 0.6294 - f1_score: 0.0608 - loss: 3.8416 - precision: 0.3991 - recall: 0.0332 - val_accuracy: 0.8585 - val_auc: 0.6831 - val_f1_score: 0.0376 - val_loss: 2.1932 - val_precision: 0.6716 - val_recall: 0.0191 - learning_rate: 1.0000e-04
# Epoch 19/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 134ms/step - accuracy: 0.8555 - auc: 0.6419 - f1_score: 0.0509 - loss: 3.8199 - precision: 0.4132 - recall: 0.0274 - val_accuracy: 0.8600 - val_auc: 0.5643 - val_f1_score: 0.0880 - val_loss: 2.3054 - val_precision: 0.6311 - val_recall: 0.0486 - learning_rate: 1.0000e-04
# Epoch 20/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 139ms/step - accuracy: 0.8557 - auc: 0.6333 - f1_score: 0.0576 - loss: 3.7130 - precision: 0.4286 - recall: 0.0311 - val_accuracy: 0.8570 - val_auc: 0.6369 - val_f1_score: 0.1081 - val_loss: 2.2121 - val_precision: 0.4972 - val_recall: 0.0612 - learning_rate: 1.0000e-04
# Epoch 21/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 140ms/step - accuracy: 0.8563 - auc: 0.6511 - f1_score: 0.0718 - loss: 3.6649 - precision: 0.4631 - recall: 0.0394 - val_accuracy: 0.8571 - val_auc: 0.7056 - val_f1_score: 0.0927 - val_loss: 2.0942 - val_precision: 0.4980 - val_recall: 0.0521 - learning_rate: 1.0000e-04
# Epoch 22/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8557 - auc: 0.6347 - f1_score: 0.0616 - loss: 3.6964 - precision: 0.4357 - recall: 0.0334 - val_accuracy: 0.8585 - val_auc: 0.6932 - val_f1_score: 0.0389 - val_loss: 2.0655 - val_precision: 0.6504 - val_recall: 0.0205 - learning_rate: 1.0000e-04
# Epoch 23/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 135ms/step - accuracy: 0.8545 - auc: 0.6342 - f1_score: 0.0547 - loss: 3.7051 - precision: 0.3823 - recall: 0.0297 - val_accuracy: 0.8596 - val_auc: 0.6322 - val_f1_score: 0.0468 - val_loss: 2.1741 - val_precision: 0.7629 - val_recall: 0.0247 - learning_rate: 1.0000e-04
# Epoch 24/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 136ms/step - accuracy: 0.8565 - auc: 0.6495 - f1_score: 0.0638 - loss: 3.5570 - precision: 0.4679 - recall: 0.0345 - val_accuracy: 0.8510 - val_auc: 0.6330 - val_f1_score: 0.1401 - val_loss: 2.2013 - val_precision: 0.3996 - val_recall: 0.0851 - learning_rate: 1.0000e-04
# Epoch 25/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 136ms/step - accuracy: 0.8576 - auc: 0.6575 - f1_score: 0.0844 - loss: 3.4997 - precision: 0.5178 - recall: 0.0463 - val_accuracy: 0.8636 - val_auc: 0.6871 - val_f1_score: 0.2039 - val_loss: 2.8099 - val_precision: 0.6121 - val_recall: 0.1240 - learning_rate: 1.0000e-04
# Epoch 26/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 136ms/step - accuracy: 0.8567 - auc: 0.6643 - f1_score: 0.0889 - loss: 3.4423 - precision: 0.4841 - recall: 0.0493 - val_accuracy: 0.8508 - val_auc: 0.6575 - val_f1_score: 0.1727 - val_loss: 3.5964 - val_precision: 0.4154 - val_recall: 0.1091 - learning_rate: 1.0000e-04
# Epoch 27/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 82s 182ms/step - accuracy: 0.8562 - auc: 0.6613 - f1_score: 0.0790 - loss: 3.4610 - precision: 0.4664 - recall: 0.0435 - val_accuracy: 0.8598 - val_auc: 0.7071 - val_f1_score: 0.0990 - val_loss: 1.9929 - val_precision: 0.6040 - val_recall: 0.0550 - learning_rate: 1.0000e-04
# Epoch 28/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 70s 151ms/step - accuracy: 0.8559 - auc: 0.6716 - f1_score: 0.0886 - loss: 3.4384 - precision: 0.4597 - recall: 0.0494 - val_accuracy: 0.8614 - val_auc: 0.6622 - val_f1_score: 0.1622 - val_loss: 2.0493 - val_precision: 0.5921 - val_recall: 0.0958 - learning_rate: 1.0000e-04
# Epoch 29/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8567 - auc: 0.6698 - f1_score: 0.0933 - loss: 3.4566 - precision: 0.4860 - recall: 0.0517 - val_accuracy: 0.8593 - val_auc: 0.7042 - val_f1_score: 0.1373 - val_loss: 1.9653 - val_precision: 0.5531 - val_recall: 0.0798 - learning_rate: 1.0000e-04
# Epoch 30/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 139ms/step - accuracy: 0.8561 - auc: 0.6712 - f1_score: 0.0798 - loss: 3.4523 - precision: 0.4624 - recall: 0.0440 - val_accuracy: 0.8628 - val_auc: 0.7160 - val_f1_score: 0.1904 - val_loss: 2.0826 - val_precision: 0.6050 - val_recall: 0.1144 - learning_rate: 1.0000e-04
# Epoch 31/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 65s 143ms/step - accuracy: 0.8567 - auc: 0.6695 - f1_score: 0.0721 - loss: 3.4163 - precision: 0.4791 - recall: 0.0393 - val_accuracy: 0.8559 - val_auc: 0.5838 - val_f1_score: 0.0038 - val_loss: 2.1735 - val_precision: 0.1522 - val_recall: 0.0020 - learning_rate: 1.0000e-04
# Epoch 32/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 66s 146ms/step - accuracy: 0.8561 - auc: 0.6647 - f1_score: 0.0857 - loss: 3.4329 - precision: 0.4651 - recall: 0.0477 - val_accuracy: 0.8567 - val_auc: 0.5960 - val_f1_score: 0.1196 - val_loss: 2.1228 - val_precision: 0.4888 - val_recall: 0.0697 - learning_rate: 1.0000e-04
# Epoch 33/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 139ms/step - accuracy: 0.8579 - auc: 0.6720 - f1_score: 0.0916 - loss: 3.4020 - precision: 0.5281 - recall: 0.0506 - val_accuracy: 0.8666 - val_auc: 0.7138 - val_f1_score: 0.2332 - val_loss: 1.9321 - val_precision: 0.6485 - val_recall: 0.1439 - learning_rate: 1.0000e-04
# Epoch 34/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 139ms/step - accuracy: 0.8574 - auc: 0.6807 - f1_score: 0.1016 - loss: 3.3594 - precision: 0.5084 - recall: 0.0569 - val_accuracy: 0.8427 - val_auc: 0.6657 - val_f1_score: 0.2456 - val_loss: 2.1333 - val_precision: 0.3893 - val_recall: 0.1783 - learning_rate: 1.0000e-04
# Epoch 35/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 137ms/step - accuracy: 0.8582 - auc: 0.6745 - f1_score: 0.1006 - loss: 3.3364 - precision: 0.5349 - recall: 0.0560 - val_accuracy: 0.8668 - val_auc: 0.7293 - val_f1_score: 0.1813 - val_loss: 1.8864 - val_precision: 0.7393 - val_recall: 0.1039 - learning_rate: 1.0000e-04
# Epoch 36/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 140ms/step - accuracy: 0.8571 - auc: 0.6747 - f1_score: 0.0945 - loss: 3.3706 - precision: 0.4981 - recall: 0.0527 - val_accuracy: 0.8556 - val_auc: 0.5611 - val_f1_score: 0.0263 - val_loss: 2.1863 - val_precision: 0.3584 - val_recall: 0.0139 - learning_rate: 1.0000e-04
# Epoch 37/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8563 - auc: 0.6789 - f1_score: 0.1069 - loss: 3.3640 - precision: 0.4776 - recall: 0.0608 - val_accuracy: 0.8624 - val_auc: 0.7444 - val_f1_score: 0.0931 - val_loss: 1.8218 - val_precision: 0.7969 - val_recall: 0.0497 - learning_rate: 1.0000e-04
# Epoch 38/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 132ms/step - accuracy: 0.8586 - auc: 0.6933 - f1_score: 0.1237 - loss: 3.2997 - precision: 0.5390 - recall: 0.0704 - val_accuracy: 0.8284 - val_auc: 0.5751 - val_f1_score: 0.1369 - val_loss: 2.3331 - val_precision: 0.2451 - val_recall: 0.0967 - learning_rate: 1.0000e-04
# Epoch 39/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 132ms/step - accuracy: 0.8568 - auc: 0.6806 - f1_score: 0.1002 - loss: 3.2927 - precision: 0.4881 - recall: 0.0563 - val_accuracy: 0.8529 - val_auc: 0.6919 - val_f1_score: 0.2971 - val_loss: 2.6320 - val_precision: 0.4686 - val_recall: 0.2214 - learning_rate: 1.0000e-04
# Epoch 40/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8580 - auc: 0.6919 - f1_score: 0.1153 - loss: 3.2683 - precision: 0.5238 - recall: 0.0653 - val_accuracy: 0.8501 - val_auc: 0.6714 - val_f1_score: 0.1324 - val_loss: 2.0077 - val_precision: 0.3834 - val_recall: 0.0815 - learning_rate: 1.0000e-04
# Epoch 41/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 140ms/step - accuracy: 0.8591 - auc: 0.7030 - f1_score: 0.1240 - loss: 3.1834 - precision: 0.5555 - recall: 0.0702 - val_accuracy: 0.8579 - val_auc: 0.6458 - val_f1_score: 0.0176 - val_loss: 2.0233 - val_precision: 0.7500 - val_recall: 0.0084 - learning_rate: 1.0000e-04
# Epoch 42/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 141ms/step - accuracy: 0.8579 - auc: 0.6966 - f1_score: 0.1065 - loss: 3.2274 - precision: 0.5234 - recall: 0.0598 - val_accuracy: 0.8513 - val_auc: 0.6612 - val_f1_score: 0.0795 - val_loss: 2.0137 - val_precision: 0.3449 - val_recall: 0.0457 - learning_rate: 1.0000e-04
# Epoch 43/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 134ms/step - accuracy: 0.8590 - auc: 0.7078 - f1_score: 0.1343 - loss: 3.1593 - precision: 0.5473 - recall: 0.0770 - val_accuracy: 0.8346 - val_auc: 0.6183 - val_f1_score: 0.1837 - val_loss: 2.2869 - val_precision: 0.3129 - val_recall: 0.1322 - learning_rate: 1.0000e-04
# Epoch 44/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 68s 150ms/step - accuracy: 0.8598 - auc: 0.7120 - f1_score: 0.1452 - loss: 3.1612 - precision: 0.5619 - recall: 0.0839 - val_accuracy: 0.8387 - val_auc: 0.5146 - val_f1_score: 0.1146 - val_loss: 2.5300 - val_precision: 0.2671 - val_recall: 0.0741 - learning_rate: 1.0000e-04
# Epoch 45/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 134ms/step - accuracy: 0.8592 - auc: 0.7049 - f1_score: 0.1357 - loss: 3.1821 - precision: 0.5498 - recall: 0.0780 - val_accuracy: 0.8561 - val_auc: 0.7111 - val_f1_score: 0.2064 - val_loss: 2.0721 - val_precision: 0.4867 - val_recall: 0.1323 - learning_rate: 1.0000e-04
# Epoch 46/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 133ms/step - accuracy: 0.8584 - auc: 0.7105 - f1_score: 0.1377 - loss: 3.1473 - precision: 0.5309 - recall: 0.0796 - val_accuracy: 0.8390 - val_auc: 0.6734 - val_f1_score: 0.2676 - val_loss: 2.6204 - val_precision: 0.3825 - val_recall: 0.2066 - learning_rate: 1.0000e-04
# Epoch 47/100
# 448/449 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8602 - auc: 0.7145 - f1_score: 0.1512 - loss: 3.1317 - precision: 0.5689 - recall: 0.0877
# Epoch 47: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 133ms/step - accuracy: 0.8602 - auc: 0.7145 - f1_score: 0.1512 - loss: 3.1317 - precision: 0.5689 - recall: 0.0877 - val_accuracy: 0.8363 - val_auc: 0.5367 - val_f1_score: 0.1254 - val_loss: 2.4465 - val_precision: 0.2668 - val_recall: 0.0833 - learning_rate: 1.0000e-04
# Epoch 48/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 132ms/step - accuracy: 0.8607 - auc: 0.7210 - f1_score: 0.1536 - loss: 3.1400 - precision: 0.5805 - recall: 0.0891 - val_accuracy: 0.8624 - val_auc: 0.7290 - val_f1_score: 0.1623 - val_loss: 1.8117 - val_precision: 0.6198 - val_recall: 0.0952 - learning_rate: 5.0000e-05
# Epoch 49/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 133ms/step - accuracy: 0.8602 - auc: 0.7250 - f1_score: 0.1624 - loss: 3.0603 - precision: 0.5621 - recall: 0.0955 - val_accuracy: 0.8590 - val_auc: 0.7548 - val_f1_score: 0.2105 - val_loss: 1.9029 - val_precision: 0.5259 - val_recall: 0.1328 - learning_rate: 5.0000e-05
# Epoch 50/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.8620 - auc: 0.7267 - f1_score: 0.1802 - loss: 3.0501 - precision: 0.5942 - recall: 0.1067 - val_accuracy: 0.8389 - val_auc: 0.6419 - val_f1_score: 0.1609 - val_loss: 2.1145 - val_precision: 0.3147 - val_recall: 0.1084 - learning_rate: 5.0000e-05
# Epoch 51/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 135ms/step - accuracy: 0.8602 - auc: 0.7267 - f1_score: 0.1662 - loss: 3.0407 - precision: 0.5607 - recall: 0.0980 - val_accuracy: 0.8676 - val_auc: 0.7554 - val_f1_score: 0.2766 - val_loss: 1.7755 - val_precision: 0.6286 - val_recall: 0.1794 - learning_rate: 5.0000e-05
# Epoch 52/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 136ms/step - accuracy: 0.8611 - auc: 0.7318 - f1_score: 0.1668 - loss: 3.0153 - precision: 0.5809 - recall: 0.0980 - val_accuracy: 0.8617 - val_auc: 0.7319 - val_f1_score: 0.1849 - val_loss: 1.7938 - val_precision: 0.5846 - val_recall: 0.1112 - learning_rate: 5.0000e-05
# Epoch 53/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 133ms/step - accuracy: 0.8615 - auc: 0.7311 - f1_score: 0.1749 - loss: 2.9973 - precision: 0.5873 - recall: 0.1034 - val_accuracy: 0.8678 - val_auc: 0.7753 - val_f1_score: 0.2228 - val_loss: 1.7005 - val_precision: 0.6924 - val_recall: 0.1339 - learning_rate: 5.0000e-05
# Epoch 54/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.8626 - auc: 0.7345 - f1_score: 0.1858 - loss: 2.9823 - precision: 0.6051 - recall: 0.1104 - val_accuracy: 0.8629 - val_auc: 0.7345 - val_f1_score: 0.1621 - val_loss: 1.8163 - val_precision: 0.6364 - val_recall: 0.0946 - learning_rate: 5.0000e-05
# Epoch 55/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8637 - auc: 0.7389 - f1_score: 0.1950 - loss: 2.9923 - precision: 0.6241 - recall: 0.1159 - val_accuracy: 0.8681 - val_auc: 0.7765 - val_f1_score: 0.3446 - val_loss: 1.6895 - val_precision: 0.5925 - val_recall: 0.2459 - learning_rate: 5.0000e-05
# Epoch 56/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 136ms/step - accuracy: 0.8620 - auc: 0.7428 - f1_score: 0.1929 - loss: 2.9982 - precision: 0.5857 - recall: 0.1160 - val_accuracy: 0.8689 - val_auc: 0.7715 - val_f1_score: 0.2237 - val_loss: 1.6923 - val_precision: 0.7234 - val_recall: 0.1337 - learning_rate: 5.0000e-05
# Epoch 57/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 61s 134ms/step - accuracy: 0.8637 - auc: 0.7428 - f1_score: 0.1891 - loss: 2.9735 - precision: 0.6299 - recall: 0.1117 - val_accuracy: 0.8569 - val_auc: 0.7156 - val_f1_score: 0.1970 - val_loss: 1.8590 - val_precision: 0.4961 - val_recall: 0.1247 - learning_rate: 5.0000e-05
# Epoch 58/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.8634 - auc: 0.7421 - f1_score: 0.1984 - loss: 2.9809 - precision: 0.6130 - recall: 0.1189 - val_accuracy: 0.8142 - val_auc: 0.6048 - val_f1_score: 0.1091 - val_loss: 2.3727 - val_precision: 0.1719 - val_recall: 0.0787 - learning_rate: 5.0000e-05
# Epoch 59/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8622 - auc: 0.7379 - f1_score: 0.1912 - loss: 2.9720 - precision: 0.5925 - recall: 0.1147 - val_accuracy: 0.8539 - val_auc: 0.6772 - val_f1_score: 0.1271 - val_loss: 1.9638 - val_precision: 0.4346 - val_recall: 0.0759 - learning_rate: 5.0000e-05
# Epoch 60/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8634 - auc: 0.7445 - f1_score: 0.2046 - loss: 2.9825 - precision: 0.6083 - recall: 0.1236 - val_accuracy: 0.8613 - val_auc: 0.6980 - val_f1_score: 0.2267 - val_loss: 1.8773 - val_precision: 0.5560 - val_recall: 0.1439 - learning_rate: 5.0000e-05
# Epoch 61/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 140ms/step - accuracy: 0.8639 - auc: 0.7425 - f1_score: 0.1973 - loss: 3.0164 - precision: 0.6262 - recall: 0.1176 - val_accuracy: 0.8710 - val_auc: 0.7708 - val_f1_score: 0.2306 - val_loss: 1.6714 - val_precision: 0.7738 - val_recall: 0.1372 - learning_rate: 5.0000e-05
# Epoch 62/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 135ms/step - accuracy: 0.8638 - auc: 0.7434 - f1_score: 0.1965 - loss: 2.9626 - precision: 0.6234 - recall: 0.1172 - val_accuracy: 0.8275 - val_auc: 0.7012 - val_f1_score: 0.3121 - val_loss: 2.3347 - val_precision: 0.3618 - val_recall: 0.2719 - learning_rate: 5.0000e-05
# Epoch 63/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 140ms/step - accuracy: 0.8631 - auc: 0.7402 - f1_score: 0.1953 - loss: 2.9785 - precision: 0.6098 - recall: 0.1166 - val_accuracy: 0.8566 - val_auc: 0.7430 - val_f1_score: 0.2531 - val_loss: 1.7938 - val_precision: 0.4942 - val_recall: 0.1732 - learning_rate: 5.0000e-05
# Epoch 64/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 141ms/step - accuracy: 0.8638 - auc: 0.7465 - f1_score: 0.2058 - loss: 2.9538 - precision: 0.6158 - recall: 0.1242 - val_accuracy: 0.8663 - val_auc: 0.7919 - val_f1_score: 0.1980 - val_loss: 1.6599 - val_precision: 0.6904 - val_recall: 0.1162 - learning_rate: 5.0000e-05
# Epoch 65/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 83s 184ms/step - accuracy: 0.8643 - auc: 0.7491 - f1_score: 0.2081 - loss: 2.9231 - precision: 0.6248 - recall: 0.1254 - val_accuracy: 0.8577 - val_auc: 0.7236 - val_f1_score: 0.2329 - val_loss: 1.8513 - val_precision: 0.5070 - val_recall: 0.1505 - learning_rate: 5.0000e-05
# Epoch 66/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 87s 190ms/step - accuracy: 0.8647 - auc: 0.7491 - f1_score: 0.2164 - loss: 2.9116 - precision: 0.6266 - recall: 0.1315 - val_accuracy: 0.8628 - val_auc: 0.7146 - val_f1_score: 0.1474 - val_loss: 1.8438 - val_precision: 0.6571 - val_recall: 0.0833 - learning_rate: 5.0000e-05
# Epoch 67/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 67s 145ms/step - accuracy: 0.8652 - auc: 0.7572 - f1_score: 0.2137 - loss: 2.8783 - precision: 0.6386 - recall: 0.1290 - val_accuracy: 0.8643 - val_auc: 0.7386 - val_f1_score: 0.1845 - val_loss: 1.7617 - val_precision: 0.6503 - val_recall: 0.1085 - learning_rate: 5.0000e-05
# Epoch 68/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 68s 150ms/step - accuracy: 0.8656 - auc: 0.7591 - f1_score: 0.2198 - loss: 2.8759 - precision: 0.6417 - recall: 0.1332 - val_accuracy: 0.8697 - val_auc: 0.7634 - val_f1_score: 0.2461 - val_loss: 1.6853 - val_precision: 0.7077 - val_recall: 0.1498 - learning_rate: 5.0000e-05
# Epoch 69/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 74s 164ms/step - accuracy: 0.8644 - auc: 0.7558 - f1_score: 0.2175 - loss: 2.8897 - precision: 0.6179 - recall: 0.1330 - val_accuracy: 0.8729 - val_auc: 0.7870 - val_f1_score: 0.3043 - val_loss: 1.6148 - val_precision: 0.6941 - val_recall: 0.1975 - learning_rate: 5.0000e-05
# Epoch 70/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 68s 149ms/step - accuracy: 0.8652 - auc: 0.7585 - f1_score: 0.2244 - loss: 2.8623 - precision: 0.6292 - recall: 0.1373 - val_accuracy: 0.8547 - val_auc: 0.6938 - val_f1_score: 0.2040 - val_loss: 1.8951 - val_precision: 0.4691 - val_recall: 0.1312 - learning_rate: 5.0000e-05
# Epoch 71/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 67s 146ms/step - accuracy: 0.8652 - auc: 0.7554 - f1_score: 0.2202 - loss: 2.8960 - precision: 0.6346 - recall: 0.1338 - val_accuracy: 0.8732 - val_auc: 0.7926 - val_f1_score: 0.3217 - val_loss: 1.5971 - val_precision: 0.6819 - val_recall: 0.2105 - learning_rate: 5.0000e-05
# Epoch 72/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 69s 151ms/step - accuracy: 0.8670 - auc: 0.7667 - f1_score: 0.2320 - loss: 2.8055 - precision: 0.6619 - recall: 0.1412 - val_accuracy: 0.8559 - val_auc: 0.7022 - val_f1_score: 0.2170 - val_loss: 1.8735 - val_precision: 0.4854 - val_recall: 0.1411 - learning_rate: 5.0000e-05
# Epoch 73/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 70s 155ms/step - accuracy: 0.8658 - auc: 0.7622 - f1_score: 0.2271 - loss: 2.8485 - precision: 0.6400 - recall: 0.1388 - val_accuracy: 0.8641 - val_auc: 0.6983 - val_f1_score: 0.1773 - val_loss: 1.8700 - val_precision: 0.6527 - val_recall: 0.1045 - learning_rate: 5.0000e-05
# Epoch 74/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 66s 145ms/step - accuracy: 0.8652 - auc: 0.7598 - f1_score: 0.2264 - loss: 2.8498 - precision: 0.6279 - recall: 0.1387 - val_accuracy: 0.8549 - val_auc: 0.7237 - val_f1_score: 0.2323 - val_loss: 1.8144 - val_precision: 0.4757 - val_recall: 0.1544 - learning_rate: 5.0000e-05
# Epoch 75/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 141ms/step - accuracy: 0.8663 - auc: 0.7668 - f1_score: 0.2376 - loss: 2.8322 - precision: 0.6395 - recall: 0.1465 - val_accuracy: 0.8700 - val_auc: 0.7964 - val_f1_score: 0.2157 - val_loss: 1.5924 - val_precision: 0.7747 - val_recall: 0.1269 - learning_rate: 5.0000e-05
# Epoch 76/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 142ms/step - accuracy: 0.8670 - auc: 0.7665 - f1_score: 0.2435 - loss: 2.8594 - precision: 0.6484 - recall: 0.1504 - val_accuracy: 0.8654 - val_auc: 0.7719 - val_f1_score: 0.3507 - val_loss: 1.6856 - val_precision: 0.5644 - val_recall: 0.2529 - learning_rate: 5.0000e-05
# Epoch 77/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 141ms/step - accuracy: 0.8666 - auc: 0.7671 - f1_score: 0.2372 - loss: 2.8288 - precision: 0.6465 - recall: 0.1459 - val_accuracy: 0.8614 - val_auc: 0.7142 - val_f1_score: 0.1523 - val_loss: 1.8068 - val_precision: 0.6013 - val_recall: 0.0880 - learning_rate: 5.0000e-05
# Epoch 78/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8647 - auc: 0.7628 - f1_score: 0.2273 - loss: 2.8507 - precision: 0.6167 - recall: 0.1400 - val_accuracy: 0.8731 - val_auc: 0.8001 - val_f1_score: 0.2678 - val_loss: 1.5711 - val_precision: 0.7597 - val_recall: 0.1638 - learning_rate: 5.0000e-05
# Epoch 79/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.8663 - auc: 0.7727 - f1_score: 0.2393 - loss: 2.8019 - precision: 0.6393 - recall: 0.1478 - val_accuracy: 0.8704 - val_auc: 0.7911 - val_f1_score: 0.2419 - val_loss: 1.6135 - val_precision: 0.7280 - val_recall: 0.1477 - learning_rate: 5.0000e-05
# Epoch 80/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 141ms/step - accuracy: 0.8661 - auc: 0.7667 - f1_score: 0.2364 - loss: 2.8072 - precision: 0.6368 - recall: 0.1458 - val_accuracy: 0.8735 - val_auc: 0.8011 - val_f1_score: 0.2991 - val_loss: 1.5675 - val_precision: 0.7162 - val_recall: 0.1899 - learning_rate: 5.0000e-05
# Epoch 81/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 66s 145ms/step - accuracy: 0.8685 - auc: 0.7757 - f1_score: 0.2570 - loss: 2.7516 - precision: 0.6660 - recall: 0.1600 - val_accuracy: 0.8714 - val_auc: 0.7972 - val_f1_score: 0.2928 - val_loss: 1.5854 - val_precision: 0.6816 - val_recall: 0.1867 - learning_rate: 5.0000e-05
# Epoch 82/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 141ms/step - accuracy: 0.8684 - auc: 0.7789 - f1_score: 0.2596 - loss: 2.7486 - precision: 0.6612 - recall: 0.1620 - val_accuracy: 0.8647 - val_auc: 0.7308 - val_f1_score: 0.3282 - val_loss: 1.8146 - val_precision: 0.5644 - val_recall: 0.2320 - learning_rate: 5.0000e-05
# Epoch 83/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 141ms/step - accuracy: 0.8683 - auc: 0.7777 - f1_score: 0.2615 - loss: 2.7448 - precision: 0.6570 - recall: 0.1640 - val_accuracy: 0.8607 - val_auc: 0.7493 - val_f1_score: 0.1511 - val_loss: 1.7335 - val_precision: 0.5839 - val_recall: 0.0878 - learning_rate: 5.0000e-05
# Epoch 84/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 68s 149ms/step - accuracy: 0.8688 - auc: 0.7803 - f1_score: 0.2590 - loss: 2.7505 - precision: 0.6694 - recall: 0.1612 - val_accuracy: 0.8737 - val_auc: 0.8037 - val_f1_score: 0.3234 - val_loss: 1.5548 - val_precision: 0.6864 - val_recall: 0.2132 - learning_rate: 5.0000e-05
# Epoch 85/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 65s 143ms/step - accuracy: 0.8679 - auc: 0.7793 - f1_score: 0.2532 - loss: 2.7183 - precision: 0.6570 - recall: 0.1574 - val_accuracy: 0.8672 - val_auc: 0.7746 - val_f1_score: 0.2367 - val_loss: 1.6375 - val_precision: 0.6579 - val_recall: 0.1471 - learning_rate: 5.0000e-05
# Epoch 86/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 74s 163ms/step - accuracy: 0.8671 - auc: 0.7773 - f1_score: 0.2514 - loss: 2.7666 - precision: 0.6440 - recall: 0.1569 - val_accuracy: 0.8643 - val_auc: 0.7670 - val_f1_score: 0.2331 - val_loss: 1.6729 - val_precision: 0.6056 - val_recall: 0.1446 - learning_rate: 5.0000e-05
# Epoch 87/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 140ms/step - accuracy: 0.8687 - auc: 0.7811 - f1_score: 0.2677 - loss: 2.7300 - precision: 0.6573 - recall: 0.1688 - val_accuracy: 0.8762 - val_auc: 0.8224 - val_f1_score: 0.3549 - val_loss: 1.4945 - val_precision: 0.6934 - val_recall: 0.2395 - learning_rate: 5.0000e-05
# Epoch 88/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 140ms/step - accuracy: 0.8696 - auc: 0.7844 - f1_score: 0.2745 - loss: 2.7317 - precision: 0.6689 - recall: 0.1732 - val_accuracy: 0.8592 - val_auc: 0.7630 - val_f1_score: 0.3084 - val_loss: 1.7262 - val_precision: 0.5171 - val_recall: 0.2211 - learning_rate: 5.0000e-05
# Epoch 89/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8703 - auc: 0.7888 - f1_score: 0.2776 - loss: 2.7056 - precision: 0.6788 - recall: 0.1750 - val_accuracy: 0.8674 - val_auc: 0.7943 - val_f1_score: 0.2335 - val_loss: 1.6079 - val_precision: 0.6671 - val_recall: 0.1427 - learning_rate: 5.0000e-05
# Epoch 90/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 139ms/step - accuracy: 0.8696 - auc: 0.7866 - f1_score: 0.2796 - loss: 2.6885 - precision: 0.6617 - recall: 0.1779 - val_accuracy: 0.8721 - val_auc: 0.7990 - val_f1_score: 0.2445 - val_loss: 1.5637 - val_precision: 0.7730 - val_recall: 0.1485 - learning_rate: 5.0000e-05
# Epoch 91/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 65s 143ms/step - accuracy: 0.8685 - auc: 0.7848 - f1_score: 0.2678 - loss: 2.6983 - precision: 0.6540 - recall: 0.1692 - val_accuracy: 0.8629 - val_auc: 0.7510 - val_f1_score: 0.2061 - val_loss: 1.7291 - val_precision: 0.5941 - val_recall: 0.1271 - learning_rate: 5.0000e-05
# Epoch 92/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 65s 143ms/step - accuracy: 0.8709 - auc: 0.7925 - f1_score: 0.2805 - loss: 2.6726 - precision: 0.6860 - recall: 0.1770 - val_accuracy: 0.8704 - val_auc: 0.7968 - val_f1_score: 0.2338 - val_loss: 1.5738 - val_precision: 0.7491 - val_recall: 0.1393 - learning_rate: 5.0000e-05
# Epoch 93/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 65s 142ms/step - accuracy: 0.8694 - auc: 0.7861 - f1_score: 0.2743 - loss: 2.6830 - precision: 0.6633 - recall: 0.1736 - val_accuracy: 0.8706 - val_auc: 0.7960 - val_f1_score: 0.2917 - val_loss: 1.5718 - val_precision: 0.6690 - val_recall: 0.1867 - learning_rate: 5.0000e-05
# Epoch 94/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 140ms/step - accuracy: 0.8696 - auc: 0.7873 - f1_score: 0.2768 - loss: 2.6465 - precision: 0.6647 - recall: 0.1754 - val_accuracy: 0.8680 - val_auc: 0.7812 - val_f1_score: 0.2242 - val_loss: 1.6137 - val_precision: 0.6951 - val_recall: 0.1353 - learning_rate: 5.0000e-05
# Epoch 95/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 62s 137ms/step - accuracy: 0.8692 - auc: 0.7830 - f1_score: 0.2721 - loss: 2.6842 - precision: 0.6619 - recall: 0.1719 - val_accuracy: 0.8789 - val_auc: 0.8283 - val_f1_score: 0.3953 - val_loss: 1.4597 - val_precision: 0.6849 - val_recall: 0.2816 - learning_rate: 5.0000e-05
# Epoch 96/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 63s 138ms/step - accuracy: 0.8699 - auc: 0.7909 - f1_score: 0.2802 - loss: 2.6642 - precision: 0.6679 - recall: 0.1780 - val_accuracy: 0.8804 - val_auc: 0.8359 - val_f1_score: 0.3622 - val_loss: 1.4358 - val_precision: 0.7538 - val_recall: 0.2414 - learning_rate: 5.0000e-05
# Epoch 97/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 66s 145ms/step - accuracy: 0.8711 - auc: 0.7911 - f1_score: 0.2905 - loss: 2.6707 - precision: 0.6785 - recall: 0.1855 - val_accuracy: 0.8679 - val_auc: 0.7967 - val_f1_score: 0.3567 - val_loss: 1.5911 - val_precision: 0.5856 - val_recall: 0.2563 - learning_rate: 5.0000e-05
# Epoch 98/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 66s 145ms/step - accuracy: 0.8706 - auc: 0.7924 - f1_score: 0.2845 - loss: 2.6668 - precision: 0.6750 - recall: 0.1810 - val_accuracy: 0.8746 - val_auc: 0.8234 - val_f1_score: 0.3640 - val_loss: 1.4853 - val_precision: 0.6607 - val_recall: 0.2509 - learning_rate: 5.0000e-05
# Epoch 99/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 64s 140ms/step - accuracy: 0.8711 - auc: 0.7950 - f1_score: 0.2896 - loss: 2.6850 - precision: 0.6788 - recall: 0.1848 - val_accuracy: 0.8771 - val_auc: 0.8215 - val_f1_score: 0.3688 - val_loss: 1.4811 - val_precision: 0.6896 - val_recall: 0.2541 - learning_rate: 5.0000e-05
# Epoch 100/100
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 65s 143ms/step - accuracy: 0.8702 - auc: 0.7935 - f1_score: 0.2854 - loss: 2.6697 - precision: 0.6666 - recall: 0.1824 - val_accuracy: 0.8749 - val_auc: 0.8146 - val_f1_score: 0.3258 - val_loss: 1.5154 - val_precision: 0.7041 - val_recall: 0.2138 - learning_rate: 5.0000e-05

# %%
model.save("/kaggle/working/model_ResNet50.h5")

# %%
train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)
# Out:
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 60s 134ms/step - accuracy: 0.8694 - auc: 0.7939 - f1_score: 0.2719 - loss: 1.5815 - precision: 0.6650 - recall: 0.1723
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - accuracy: 0.8744 - auc: 0.8107 - f1_score: 0.3229 - loss: 1.5277 - precision: 0.6997 - recall: 0.2115

# %%
metric_list = ["Loss","Accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))
# Out:
# Model Scores
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Metric Name</th>
#       <th>Train</th>
#       <th>Validate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Loss</td>
#       <td>1.580</td>
#       <td>1.515</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Accuracy</td>
#       <td>0.870</td>
#       <td>0.875</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Precision</td>
#       <td>0.673</td>
#       <td>0.704</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Recall</td>
#       <td>0.174</td>
#       <td>0.214</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Auc</td>
#       <td>0.794</td>
#       <td>0.815</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>F1_Score</td>
#       <td>0.275</td>
#       <td>0.326</td>
#     </tr>
#   </tbody>
# </table>

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 14s 94ms/step

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Confusion matrix, without normalization
#
# [[ 95 150  57 231 142 195  88]
#  [  7  18   7  24  15  27  13]
#  [ 91 142  43 245 164 235 104]
#  [137 264  93 430 281 389 180]
#  [ 98 180  68 293 183 274 137]
#  [105 196  61 323 198 242 122]
#  [ 69 123  32 198 127 202  80]]
# <ipython-input-29-a56f347fa47c>:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()
# Out:
# <ipython-input-30-e68e0cb2e8fd>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# # 3. Alex Net

# %%
# AlexNet Model
model = Sequential([
    Conv2D(96, (11, 11), strides=4, activation='relu', input_shape=IMAGE_SHAPE),
    BatchNormalization(),
    MaxPooling2D((3, 3), strides=2),

    Conv2D(256, (5, 5), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D((3, 3), strides=2),

    Conv2D(384, (3, 3), padding='same', activation='relu'),
    Conv2D(384, (3, 3), padding='same', activation='relu'),
    Conv2D(256, (3, 3), padding='same', activation='relu'),
    MaxPooling2D((3, 3), strides=2),

    Flatten(),
    Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),
    
    Dense(4096, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),
    
    Dense(7, activation='softmax')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-75de0e0f78b7> in <cell line: 2>()
#       1 # AlexNet Model
#       2 model = Sequential([
# ----> 3     Conv2D(96, (11, 11), strides=4, activation='relu', input_shape=IMAGE_SHAPE),
#       4     BatchNormalization(),
#       5     MaxPooling2D((3, 3), strides=2),
#
# NameError: name 'Conv2D' is not defined

# %%
# Compile model

def f1_score(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc'),
      f1_score,
]

adam = tf.keras.optimizers.Adam(learning_rate=ADAM_LEARNING_RATE, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

model.compile(optimizer=adam, loss='categorical_crossentropy',metrics=METRICS)

# %%
# Run Model

counter = Counter(train_dataset.classes)                          
max_val = float(max(counter.values()))       
class_weights = {class_id : round(max_val/num_images,2) for class_id, num_images in counter.items()}  

lrd = ReduceLROnPlateau(monitor = 'val_loss',patience = PATIENCE,verbose = 1,factor = 0.50, min_lr = 1e-10)
mcp = ModelCheckpoint('model_alexnet.keras')
es = EarlyStopping(verbose=1, patience=20)

history=model.fit(train_dataset,
                  validation_data=test_dataset,
                  epochs = EPOCHS,
                  verbose =1,
                  callbacks = [lrd,mcp,es], 
                  class_weight = class_weights)

# %%
model.save("/kaggle/working/model_alex_net.h5")

# %%
train_evalation = model.evaluate(train_dataset)
test_evaluation = model.evaluate(test_dataset)

# %%
metric_list = ["Loss","Accuracy", "Precision", "Recall", "Auc", "F1_Score"]

df = pd.DataFrame(list(zip(metric_list, 
                           [round(num, 3) for num in train_evalation], 
                           [round(num, 3) for num in test_evaluation])),
                  columns=['Metric Name', 'Train', 'Validate'])

print('\n\nModel Scores\n')

HTML(df.to_html(escape=False))

# %%
hs=history.history

acc = hs['accuracy']
val_acc = hs['val_accuracy']
loss =  hs['loss']
val_loss = hs['val_loss']
auc =  hs['auc']
val_auc = hs['val_auc']
precision =hs['precision']
val_precision =hs['val_precision']
f1 = hs['f1_score']
val_f1 = hs['val_f1_score']              

plt.style.use('Solarize_Light2')

fig, (ax1, ax2,ax3,ax4,ax5) = plt.subplots(1,5, figsize= (20,5))
fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

ax1.plot(range(1, len(acc) + 1), acc)
ax1.plot(range(1, len(val_acc) + 1), val_acc)
ax1.set_title('History of Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend(['training', 'validation'])


ax2.plot(range(1, len(loss) + 1), loss)
ax2.plot(range(1, len(val_loss) + 1), val_loss)
ax2.set_title('History of Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend(['training', 'validation'])

ax3.plot(range(1, len(auc) + 1), auc)
ax3.plot(range(1, len(val_auc) + 1), val_auc)
ax3.set_title('History of AUC')
ax3.set_xlabel('Epochs')
ax3.set_ylabel('AUC')
ax3.legend(['training', 'validation'])

ax4.plot(range(1, len(precision) + 1), precision)
ax4.plot(range(1, len(val_precision) + 1), val_precision)
ax4.set_title('History of Precision')
ax4.set_xlabel('Epochs')
ax4.set_ylabel('Precision')
ax4.legend(['training', 'validation'])

ax5.plot(range(1, len(f1) + 1), f1)
ax5.plot(range(1, len(val_f1) + 1), val_f1)
ax5.set_title('History of F1-score')
ax5.set_xlabel('Epochs')
ax5.set_ylabel('F1 score')
ax5.legend(['training', 'validation'])

plt.show()

# %%
y_true = test_dataset.classes
y_pred =  model.predict(test_dataset)
y_pred= tf.argmax(y_pred, axis = 1).numpy()

cm = confusion_matrix(y_true = y_true, y_pred = y_pred)

# %%
plt.rcParams['figure.figsize'] = (14,7)

plt.style.use('seaborn-darkgrid')
plt.imshow(cm, interpolation='nearest', cmap='Reds')
plt.title('Confusion matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=45)
plt.yticks(tick_marks, classes)    

print('Confusion matrix, without normalization\n')   
print(cm)

print("\n\n")
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j],
        horizontalalignment="center",
        color="white" if cm[i, j] > thresh else "black")

plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# %%
plt.style.use('seaborn')

cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
fig, ax = plt.subplots(figsize=(12,6))

im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(xticks=np.arange(cm.shape[1]),
       yticks=np.arange(cm.shape[0]),
       xticklabels=classes, yticklabels=classes,
       title = 'Normalized confusion matrix',
       ylabel='True label',
       xlabel='Predicted label')

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")


fmt = '.2f' 
thresh = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], fmt),
                ha="center", va="center",
                color="white" if cm[i, j] > thresh else "black")

fig.tight_layout()
plt.show()
